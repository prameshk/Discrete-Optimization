# %% [markdown]
# # Around the world in X number of days using Traveling Salesman Problem (TSP)

# %% [markdown]
# In this tutorial, we will learn how to exactly and heuristically solve TSP.

# %%
# Copyright 2020, Gurobi Optimization, LLC
import csv, time, math, random  
from gurobipy import * 
import networkx as nx # For drawing tours and subtours
from haversine import haversine, Unit # For computing the haversine distance

# %% [markdown]
# ### Reading data

# %%
capitals = {} # Dictionary of capitals with values as coordinates
with open('coord_ind_cap.csv', newline='') as csvfile:
    reader = csv.reader(csvfile) # reader
    next(reader) # skip header
    for row in reader:
        capitals[row[1], row[0]] = (float(row[2]), float(row[3]))

dist_matrix = {}
for c1 in capitals:
    for c2 in capitals:
        dist_matrix[c1, c2] = haversine(capitals[c1], capitals[c2], unit=Unit.KILOMETERS) # computes the haversine distance between two coordinates

neighbors = {i:[] for i in capitals} # Adjacency dictionary

for i, j in dist_matrix:
    if j not in neighbors[i]:
        neighbors[i].append(j)
    if i not in neighbors[j]:
        neighbors[j].append(i)

# %%
# Drawing on the map
# Drawing the tour/subtour
import folium # Library for creating the maps
def draw_tour(edges):     
    # The averate coordinate will be used for setting up the initial map
    average_lat = sum(lat for lat, lon in capitals.values()) / len(capitals)
    average_lon = sum(lon for lat, lon in capitals.values()) / len(capitals)
    
    # Intialize the map with location of the center of the map and zoom level
    mymap = folium.Map(location=[average_lat, average_lon], zoom_start=4)
    
    # We put a small circle at each capital.   
    for c in capitals:
        folium.Circle([capitals[c][0], capitals[c][1]],radius=2000, color='red', fill=True, fill_color='red', 
                      fill_opacity=0.7,popup=c).add_to(mymap)

    # We put edges between coordinates
    for i, j in edges:
        coord1 = (capitals[i][0], capitals[i][1])
        coord2 = (capitals[j][0], capitals[j][1])
        folium.PolyLine([coord1, coord2], color="blue", weight=2.5, opacity=1).add_to(mymap)
        
    return mymap

# %% [markdown]
# ### MTZ model

# %%
m = Model() # Initialize the model

# Define decision variables
x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals} # Whether an edge is part of tour or not
u = {i: m.addVar(vtype=GRB.INTEGER) for i in capitals} # Order in which each capital is visited

# Add constraints
for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if i != j]) == 1) 
    m.addConstr(sum([x[j, i] for j in capitals if i != j]) == 1)

# Without loss of generality, let's assume the first city is the first capital in the list
first = list(capitals.keys())[0]

m.addConstr(u[first] == 1) # The order for first city is 1


for i in capitals:
    if i != first:
        m.addConstr(u[i] <= len(capitals)) # Order should be less than the number of cities
        m.addConstr(u[i] >= 2)

for i, j in dist_matrix:
    if i != first and j != first:
        m.addConstr(u[i] - u[j] + 1 <= (len(capitals) - 1) * (1 - x[i, j])) # Subtour elimination


obj = sum([dist_matrix[k] * x[k] for k in dist_matrix]) # Total cost of tour
m.setObjective(obj, sense=GRB.MINIMIZE)
m.optimize()
print(m.status)
edges  = [k for k in x if x[k].x > 0.4] # Edges in the optimal tour
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 1224 rows, 1190 columns and 5512 nonzeros
# Model fingerprint: 0xf0524df0
# Variable types: 0 continuous, 1190 integer (1156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 100 rows and 35 columns
# Presolve time: 0.00s
# Presolved: 1124 rows, 1155 columns, 5412 nonzeros
# Variable types: 0 continuous, 1155 integer (1122 binary)
# Found heuristic solution: objective 48270.923208
#
# Root relaxation: objective 1.137562e+04, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11375.6174    0   58 48270.9232 11375.6174  76.4%     -    0s
# H    0     0                    15983.567037 11375.6174  28.8%     -    0s
# H    0     0                    15870.553295 11375.6174  28.3%     -    0s
#      0     0 12132.8050    0   76 15870.5533 12132.8050  23.6%     -    0s
#      0     0 12132.8050    0   76 15870.5533 12132.8050  23.6%     -    0s
# H    0     0                    15714.680051 12160.7217  22.6%     -    0s
#      0     0 12195.2862    0   64 15714.6801 12195.2862  22.4%     -    0s
#      0     0 12195.2862    0   63 15714.6801 12195.2862  22.4%     -    0s
# H    0     0                    14430.001138 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   61 14430.0011 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   59 14430.0011 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   40 14430.0011 12195.2862  15.5%     -    0s
# H    0     0                    13981.440418 12195.2862  12.8%     -    0s
#      0     0 12223.4413    0   47 13981.4404 12223.4413  12.6%     -    0s
#      0     0 12223.4413    0   52 13981.4404 12223.4413  12.6%     -    0s
#      0     0 12223.4413    0   49 13981.4404 12223.4413  12.6%     -    0s
# H    0     0                    13605.013822 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   59 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   68 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   63 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   87 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   92 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   96 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12238.8407    0   99 13605.0138 12238.8407  10.0%     -    0s
#      0     0 12244.4290    0   90 13605.0138 12244.4290  10.0%     -    0s
#      0     0 12245.4035    0   92 13605.0138 12245.4035  10.0%     -    0s
#      0     0 12245.4035    0   88 13605.0138 12245.4035  10.0%     -    0s
#      0     0 12249.8106    0   90 13605.0138 12249.8106  10.0%     -    0s
# H    0     0                    13414.350579 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   89 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   92 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   39 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   60 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   49 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   49 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   46 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   42 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12255.8990    0   61 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   76 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   90 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   88 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   89 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   88 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12269.5062    0   85 13414.3506 12269.5062  8.53%     -    0s
#      0     0 12275.6888    0   69 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   69 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   73 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     2 12276.8600    0   80 13414.3506 12276.8600  8.48%     -    0s
# H  119   128                    13325.452108 12280.3723  7.84%  15.6    1s
# H  175   202                    13170.721334 12280.3723  6.76%  13.5    1s
# H  182   202                    13095.327926 12280.3723  6.22%  13.5    1s
# H 1515  1178                    13011.008213 12280.3723  5.62%   8.8    1s
# H 2763  1801                    12941.570242 12294.6459  5.00%   9.6    1s
# H 2807  1759                    12922.738393 12294.6459  4.86%   9.9    2s
# H 2812  1675                    12894.123079 12294.6459  4.65%  10.0    2s
# H 4565  2020                    12892.106846 12296.3816  4.62%  10.1    2s
# *14351  5131              36    12771.361266 12351.8152  3.29%   9.3    3s
# H27657  6643                    12695.760679 12470.6006  1.77%   9.2    4s
#  31303  6735 12579.1661   47   94 12695.7607 12486.7422  1.65%   9.3    5s
#
# Cutting planes:
#   Learned: 19
#   Gomory: 79
#   Lift-and-project: 2
#   Cover: 17
#   Implied bound: 15
#   Projected implied bound: 10
#   MIR: 63
#   StrongCG: 3
#   Flow cover: 201
#   Inf proof: 20
#   Zero half: 22
#   RLT: 28
#   Relax-and-lift: 39
#
# Explored 44529 nodes (455601 simplex iterations) in 6.80 seconds (3.97 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 10: 12695.8 12771.4 12892.1 ... 13325.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%
# 2

# %%
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e954ab71449bd5a5f8516ef4be54f175 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e954ab71449bd5a5f8516ef4be54f175&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e954ab71449bd5a5f8516ef4be54f175 = L.map(
#                 &quot;map_e954ab71449bd5a5f8516ef4be54f175&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34b4903fc48196fbfdf6105b830dae34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_34b4903fc48196fbfdf6105b830dae34.addTo(map_e954ab71449bd5a5f8516ef4be54f175);
#
#
#             var circle_4ce000df794b656a6386d4d44094b20c = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e954ab71449bd5a5f8516ef4be54f175);
#
#
#         var popup_3d9779ec44c63de927faddc78c4919d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46e16fa4f3d190c4591a0701ac60ae2c = $(`&lt;div id=&quot;html_46e16fa4f3d190c4591a0701ac60ae2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_3d9779ec44c63de927faddc78c4919d8.setContent(html_46e16fa4f3d190c4591a0701ac60ae2c);
#
#
#
#         circle_4ce000df794b656a6386d4d44094b20c.bindPopup(popup_3d9779ec44c63de927faddc78c4919d8)
#         ;
#
#
#
#
#             var circle_91f854ff657024997fbbe3f6766f629b = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e954ab71449bd5a5f8516ef4be54f175);
#
#
#         var popup_81cf696aac43effdcd19dad08402b25b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f77cbdf67f7263fccdae8a102e6fbf3 = $(`&lt;div id=&quot;html_5f77cbdf67f7263fccdae8a102e6fbf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_81cf696aac43effdcd19dad08402b25b.setContent(html_5f77cbdf67f7263fccdae8a102e6fbf3);
#
#
#
#         circle_91f854ff657024997fbbe3f6766f629b.bindPopup(popup_81cf696aac43effdcd19dad08402b25b)
#         ;
#
#
#
#
#             var circle_fa7f1cd596210a3b4f594cec71a17412 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e954ab71449bd5a5f8516ef4be54f175);
#
#
#         var popup_261e106171cdea66d5c5ba95eac451d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62c958134b5135095729a3730533fd06 = $(`&lt;div id=&quot;html_62c958134b5135095729a3730533fd06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_261e106171cdea66d5c5ba95eac451d7.setContent(html_62c958134b5135095729a3730533fd06);
#
#
#
#         circle_fa7f1cd596210a3b4f594cec71a17412.bindPopup(popup_261e106171cdea66d5c5ba95eac451d7)
#         ;
#
#
#
#
#             var circle_bd369f2031c723747830ebefcdec8b6c = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ### Formulation with alternative subtour constraints

# %%
m = Model()
x = {(i, j): m.addVar(vtype = GRB.BINARY, name = f'x_{i},{j}') for i in capitals for j in capitals}
q = {(i, j): m.addVar(vtype = GRB.CONTINUOUS, name=f'q_{i},{j}') for i in capitals for j in capitals}

for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if j != i]) == 1)
    m.addConstr(sum([x[j, i] for j in capitals if j != i]) == 1)

first = list(capitals.keys())[0]

m.addConstr(sum([q[first, j] for j in capitals]) == len(capitals), name = 'len')
m.addConstr(sum([q[j, first] for j in capitals]) == 1, name = 'first')

for i in capitals:
    if i != first:
        m.addConstr(sum([q[j, i] for j in capitals if j != i]) - sum([q[i, j] for j in capitals if j != i]) == 1, name = f'cons_{i}')

for i in capitals:
    for j in capitals:
        if i != j:
            m.addConstr(q[i,j] <= (len(capitals) + 2) * x[i, j])

obj = sum([dist_matrix[k] * x[k] for k in dist_matrix])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.optimize()
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 1225 rows, 2312 columns and 6734 nonzeros
# Model fingerprint: 0x3b11d716
# Variable types: 1156 continuous, 1156 integer (1156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 0 rows and 67 columns
# Presolve time: 0.01s
# Presolved: 1225 rows, 2245 columns, 6734 nonzeros
# Variable types: 1123 continuous, 1122 integer (1122 binary)
# Found heuristic solution: objective 62866.638909
# Found heuristic solution: objective 38930.395746
#
# Root relaxation: objective 1.168296e+04, 1937 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11682.9644    0   57 38930.3957 11682.9644  70.0%     -    0s
# H    0     0                    16209.714216 11682.9644  27.9%     -    0s
# H    0     0                    13683.226515 11682.9644  14.6%     -    0s
#      0     0 12429.1689    0   77 13683.2265 12429.1689  9.16%     -    0s
# H    0     0                    13458.514337 12429.1689  7.65%     -    0s
#      0     0 12526.0570    0   67 13458.5143 12526.0570  6.93%     -    0s
#      0     0 12526.0570    0   67 13458.5143 12526.0570  6.93%     -    0s
#      0     0 12662.6050    0   75 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   55 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   72 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   27 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   27 13458.5143 12662.6050  5.91%     -    0s
# H    0     0                    13368.271691 12662.6050  5.28%     -    0s
# *    0     0               0    12695.760679 12695.7607  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Lift-and-project: 7
#   Implied bound: 29
#   MIR: 12
#   Flow cover: 34
#   Flow path: 10
#   Network: 14
#
# Explored 1 nodes (4414 simplex iterations) in 0.39 seconds (0.27 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 7: 12695.8 13368.3 13458.5 ... 62866.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%

# %%
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb46b1f893c938dc3ba08daaa0c3e788 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb46b1f893c938dc3ba08daaa0c3e788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb46b1f893c938dc3ba08daaa0c3e788 = L.map(
#                 &quot;map_eb46b1f893c938dc3ba08daaa0c3e788&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef1917e81b4dececd5dcd5b467bf61a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef1917e81b4dececd5dcd5b467bf61a6.addTo(map_eb46b1f893c938dc3ba08daaa0c3e788);
#
#
#             var circle_22bc261b8058d8bbcdb0e5ab7c657411 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eb46b1f893c938dc3ba08daaa0c3e788);
#
#
#         var popup_be5b8d598ea05314557dee18978ad309 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c415a4e57355dadc5c69bda444e08009 = $(`&lt;div id=&quot;html_c415a4e57355dadc5c69bda444e08009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_be5b8d598ea05314557dee18978ad309.setContent(html_c415a4e57355dadc5c69bda444e08009);
#
#
#
#         circle_22bc261b8058d8bbcdb0e5ab7c657411.bindPopup(popup_be5b8d598ea05314557dee18978ad309)
#         ;
#
#
#
#
#             var circle_e2659302455697fa80e375d6e64a70a9 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eb46b1f893c938dc3ba08daaa0c3e788);
#
#
#         var popup_88a5576ca6c61a51d24acccb211eb825 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_000bbecbb57c32bee3e097f03a41c598 = $(`&lt;div id=&quot;html_000bbecbb57c32bee3e097f03a41c598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_88a5576ca6c61a51d24acccb211eb825.setContent(html_000bbecbb57c32bee3e097f03a41c598);
#
#
#
#         circle_e2659302455697fa80e375d6e64a70a9.bindPopup(popup_88a5576ca6c61a51d24acccb211eb825)
#         ;
#
#
#
#
#             var circle_e9538a5c9eac0a3aab7666eac6756d02 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eb46b1f893c938dc3ba08daaa0c3e788);
#
#
#         var popup_36464d8d33c004a9cba559fa082c3790 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e8d68a31389f04606932c415241b4ba = $(`&lt;div id=&quot;html_0e8d68a31389f04606932c415241b4ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_36464d8d33c004a9cba559fa082c3790.setContent(html_0e8d68a31389f04606932c415241b4ba);
#
#
#
#         circle_e9538a5c9eac0a3aab7666eac6756d02.bindPopup(popup_36464d8d33c004a9cba559fa082c3790)
#         ;
#
#
#
#
#             var circle_6d8cb3a0d0a2e205776d2ef11d1c0254 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## DFJ

# %%
from itertools import combinations # for obtaining subsets

m = Model()
x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals if i != j}

for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if i != j]) == 1)
    m.addConstr(sum([x[j, i] for j in capitals if i != j]) == 1)


obj = sum([dist_matrix[k] * x[k] for k in dist_matrix if k[0] != k[1]])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.Params.OutputFlag = 0

# %%
m.optimize()

# %%
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68ee16a9107e15bb78bb2d910e22b6d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68ee16a9107e15bb78bb2d910e22b6d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68ee16a9107e15bb78bb2d910e22b6d7 = L.map(
#                 &quot;map_68ee16a9107e15bb78bb2d910e22b6d7&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4150731941daaf2a48fe48969f8dc5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f4150731941daaf2a48fe48969f8dc5f.addTo(map_68ee16a9107e15bb78bb2d910e22b6d7);
#
#
#             var circle_74111ba8d7908c460ddea0ee6f858564 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68ee16a9107e15bb78bb2d910e22b6d7);
#
#
#         var popup_9d6ea1431f3bcddaf30f20c25bbda715 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49472cf379f022eae22ac7ed9f900a1a = $(`&lt;div id=&quot;html_49472cf379f022eae22ac7ed9f900a1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_9d6ea1431f3bcddaf30f20c25bbda715.setContent(html_49472cf379f022eae22ac7ed9f900a1a);
#
#
#
#         circle_74111ba8d7908c460ddea0ee6f858564.bindPopup(popup_9d6ea1431f3bcddaf30f20c25bbda715)
#         ;
#
#
#
#
#             var circle_4fe7ad127bbe794734135716ee622225 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68ee16a9107e15bb78bb2d910e22b6d7);
#
#
#         var popup_05fe206c4a1bd8bed24f1c1f8992f9dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e61543173122eb9e99ca6237a5ec5102 = $(`&lt;div id=&quot;html_e61543173122eb9e99ca6237a5ec5102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_05fe206c4a1bd8bed24f1c1f8992f9dd.setContent(html_e61543173122eb9e99ca6237a5ec5102);
#
#
#
#         circle_4fe7ad127bbe794734135716ee622225.bindPopup(popup_05fe206c4a1bd8bed24f1c1f8992f9dd)
#         ;
#
#
#
#
#             var circle_5e95a194d953d5b43d9a8c6d5de3025b = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_68ee16a9107e15bb78bb2d910e22b6d7);
#
#
#         var popup_882b4ff6ff730844a8cd61455cf6187c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dd1a0fe09e9116174b60152d6fe6dfd = $(`&lt;div id=&quot;html_2dd1a0fe09e9116174b60152d6fe6dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_882b4ff6ff730844a8cd61455cf6187c.setContent(html_2dd1a0fe09e9116174b60152d6fe6dfd);
#
#
#
#         circle_5e95a194d953d5b43d9a8c6d5de3025b.bindPopup(popup_882b4ff6ff730844a8cd61455cf6187c)
#         ;
#
#
#
#
#             var circle_30e1fa978f3e59869074cd9e216cc950 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
def find_subtours(edges):
    subtours = []
    while edges:
        (i, j) = edges.pop(0)
        visited = [i, j]
        stop = False
        while not stop:
            neighbors = [k for k in edges if k[0] == j]
            if neighbors[0][1] in visited:
                visited.append(neighbors[0][1])
                edges.remove(neighbors[0])
                subtours.append(visited)
                stop = True
            else:
                visited.append(neighbors[0][1])
                (i, j) = neighbors[0]
                edges.remove(neighbors[0])
    return subtours
iterations = 0

# %% [markdown]
# ### We repeatedly add subtour elimination constraints until we get a tour

# %%
subtours = find_subtours(edges)

for s in subtours:
    tmp = 0; edge_count = 0
    for n in range(len(s)):
        if n != 0:
            tmp += x[s[n-1], s[n]]
            edge_count += 1
    m.addConstr(tmp <= edge_count - 1)

m.update()
m.optimize()
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
subtours = find_subtours(edges)
iterations +=1 
print(iterations)


edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# 22
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82ed1fa64560d147eba80224b1408078 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82ed1fa64560d147eba80224b1408078&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82ed1fa64560d147eba80224b1408078 = L.map(
#                 &quot;map_82ed1fa64560d147eba80224b1408078&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eafc5e8461816b73aebe4d8287347ff0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eafc5e8461816b73aebe4d8287347ff0.addTo(map_82ed1fa64560d147eba80224b1408078);
#
#
#             var circle_17a71aa7b095bb5cb513482f516aa31e = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82ed1fa64560d147eba80224b1408078);
#
#
#         var popup_ee3b1a9d069f6f997e534ddc1d7fc819 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e86e571477b924857949e93af7b9de33 = $(`&lt;div id=&quot;html_e86e571477b924857949e93af7b9de33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_ee3b1a9d069f6f997e534ddc1d7fc819.setContent(html_e86e571477b924857949e93af7b9de33);
#
#
#
#         circle_17a71aa7b095bb5cb513482f516aa31e.bindPopup(popup_ee3b1a9d069f6f997e534ddc1d7fc819)
#         ;
#
#
#
#
#             var circle_a3a2ee6b14f9374f6a3ebb90c4bd0ee0 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82ed1fa64560d147eba80224b1408078);
#
#
#         var popup_c228844dcf9f25495f6a575b48dbd4bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6c2b594b4e11089780501986bbe30c7 = $(`&lt;div id=&quot;html_e6c2b594b4e11089780501986bbe30c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_c228844dcf9f25495f6a575b48dbd4bb.setContent(html_e6c2b594b4e11089780501986bbe30c7);
#
#
#
#         circle_a3a2ee6b14f9374f6a3ebb90c4bd0ee0.bindPopup(popup_c228844dcf9f25495f6a575b48dbd4bb)
#         ;
#
#
#
#
#             var circle_286e1a167fe96c8157ad5fc2800982be = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_82ed1fa64560d147eba80224b1408078);
#
#
#         var popup_dc0bec9d0ec6dcaef47a0ac7c3fda2f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ece1772427e9b5667adb897ae40c73e0 = $(`&lt;div id=&quot;html_ece1772427e9b5667adb897ae40c73e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_dc0bec9d0ec6dcaef47a0ac7c3fda2f7.setContent(html_ece1772427e9b5667adb897ae40c73e0);
#
#
#
#         circle_286e1a167fe96c8157ad5fc2800982be.bindPopup(popup_dc0bec9d0ec6dcaef47a0ac7c3fda2f7)
#         ;
#
#
#
#
#             var circle_611227f4721aa915e837068322b2ea78 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
print('TSP solved in %d iterations'%iterations)
print('cost of the tour is: %f'%m.objVal)
# Out:
# TSP solved in 22 iterations
# cost of the tour is: 12695.760679

# %% [markdown]
# #### To sutomate this process, we route a subroutine "subtourelim" and pass it in a callback function. This is how you implement a version of branch-and-cut

# %%
# Callback - use lazy constraints to eliminate sub-tours
def subtourelim(model, where):

    if where == GRB.Callback.MIPSOL:
        vals = model.cbGetSolution(model._x) 

        
        
        edges  = [k for k in m._x if vals[k] > 0.4]
        subtours = find_subtours(edges)
        print('It: %d and # subtours: %d'%(m._iterations, len(subtours)))
        if len(subtours) > 1:
            for s in subtours:
                tmp = 0; edge_count = 0
                for n in range(len(s)):
                    if n != 0:
                        tmp += model._x[s[n-1], s[n]]
                        edge_count += 1
            
                model.cbLazy(tmp <= edge_count - 1)
            
            
        model._iterations += 1

# %%
m = Model()
m._x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals if i != j}
m._iterations = 0
for i in capitals:
    m.addConstr(sum([m._x[i, j] for j in capitals if i != j]) == 1)
    m.addConstr(sum([m._x[j, i] for j in capitals if i != j]) == 1)


obj = sum([dist_matrix[k] * m._x[k] for k in dist_matrix if k[0] != k[1]])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.Params.lazyConstraints = 1
m.optimize(subtourelim)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 68 rows, 1122 columns and 2244 nonzeros
# Model fingerprint: 0xa14f37ca
# Variable types: 0 continuous, 1122 integer (1122 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# It: 0 and # subtours: 2
# Presolve time: 0.00s
# Presolved: 68 rows, 1122 columns, 2244 nonzeros
# Variable types: 0 continuous, 1122 integer (1122 binary)
# It: 1 and # subtours: 16
# It: 2 and # subtours: 17
#
# Root relaxation: objective 1.227256e+04, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12272.5573    0   30          - 12272.5573      -     -    0s
# It: 3 and # subtours: 10
# It: 4 and # subtours: 6
# It: 5 and # subtours: 10
# It: 6 and # subtours: 6
#      0     0 12432.9131    0   52          - 12432.9131      -     -    0s
# It: 7 and # subtours: 4
#      0     2 12432.9131    0   52          - 12432.9131      -     -    0s
# It: 8 and # subtours: 3
# It: 9 and # subtours: 7
# It: 10 and # subtours: 2
# It: 11 and # subtours: 4
# It: 12 and # subtours: 4
# It: 13 and # subtours: 3
# It: 14 and # subtours: 4
# It: 15 and # subtours: 4
# It: 16 and # subtours: 5
# It: 17 and # subtours: 6
# It: 18 and # subtours: 3
# It: 19 and # subtours: 3
# It: 20 and # subtours: 4
# It: 21 and # subtours: 4
# It: 22 and # subtours: 3
# It: 23 and # subtours: 3
# It: 24 and # subtours: 3
# It: 25 and # subtours: 3
# It: 26 and # subtours: 4
# It: 27 and # subtours: 4
# It: 28 and # subtours: 4
# It: 29 and # subtours: 4
# It: 30 and # subtours: 4
# It: 31 and # subtours: 3
# It: 32 and # subtours: 2
# It: 33 and # subtours: 1
# H  588   560                    17880.142765 12498.8992  30.1%   5.4    0s
# It: 34 and # subtours: 3
# It: 35 and # subtours: 3
# It: 36 and # subtours: 3
# It: 37 and # subtours: 3
# It: 38 and # subtours: 2
# It: 39 and # subtours: 3
# It: 40 and # subtours: 3
# It: 41 and # subtours: 3
# It: 42 and # subtours: 3
# It: 43 and # subtours: 1
# *  835   838              27    13928.113794 12498.8992  10.3%   5.2    0s
# It: 44 and # subtours: 2
# It: 45 and # subtours: 5
# It: 46 and # subtours: 3
# It: 47 and # subtours: 1
# *  945   965              36    13086.948748 12505.4103  4.44%   5.1    0s
# It: 48 and # subtours: 2
# It: 49 and # subtours: 2
# It: 50 and # subtours: 3
# It: 51 and # subtours: 2
# It: 52 and # subtours: 1
# * 1272  1104              17    12770.158936 12505.4103  2.07%   4.8    0s
# It: 53 and # subtours: 2
# It: 54 and # subtours: 1
# * 1333  1106              17    12732.830874 12505.4103  1.79%   4.7    0s
# It: 55 and # subtours: 1
# * 1436  1129              17    12711.632015 12505.4103  1.62%   4.6    0s
# It: 56 and # subtours: 2
# It: 57 and # subtours: 3
# It: 58 and # subtours: 1
# H 1656  1132                    12701.849059 12505.4103  1.55%   4.6    0s
# It: 59 and # subtours: 2
# It: 60 and # subtours: 1
# * 2129  1164              15    12695.760679 12532.4471  1.29%   4.6    0s
# It: 61 and # subtours: 2
#
# Cutting planes:
#   Cover: 2
#   Lazy constraints: 218
#
# Explored 4231 nodes (16835 simplex iterations) in 0.33 seconds (0.13 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 8: 12695.8 12701.8 12711.6 ... 17880.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%
#
# User-callback calls 8670, time in user-callback 0.07 sec

# %%
edges  = [k for k in m._x if m._x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2c746c232207421608079f5785502e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2c746c232207421608079f5785502e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2c746c232207421608079f5785502e8 = L.map(
#                 &quot;map_a2c746c232207421608079f5785502e8&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cb780c43cb52aca7a633e00dcfc4e3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1cb780c43cb52aca7a633e00dcfc4e3d.addTo(map_a2c746c232207421608079f5785502e8);
#
#
#             var circle_2e112b9a6efd620204e78a10bcb0325a = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2c746c232207421608079f5785502e8);
#
#
#         var popup_58b2478d3ef51c3de1c5257c02d9c9d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68e1e9bb91558b559b28713a8ba20564 = $(`&lt;div id=&quot;html_68e1e9bb91558b559b28713a8ba20564&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_58b2478d3ef51c3de1c5257c02d9c9d9.setContent(html_68e1e9bb91558b559b28713a8ba20564);
#
#
#
#         circle_2e112b9a6efd620204e78a10bcb0325a.bindPopup(popup_58b2478d3ef51c3de1c5257c02d9c9d9)
#         ;
#
#
#
#
#             var circle_0a504b75dd85a355b1a9a69bfa28c977 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2c746c232207421608079f5785502e8);
#
#
#         var popup_c870b9f83f64cd613f67b5665ac426a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a94a604dc38c210ce03011b7f051d345 = $(`&lt;div id=&quot;html_a94a604dc38c210ce03011b7f051d345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_c870b9f83f64cd613f67b5665ac426a3.setContent(html_a94a604dc38c210ce03011b7f051d345);
#
#
#
#         circle_0a504b75dd85a355b1a9a69bfa28c977.bindPopup(popup_c870b9f83f64cd613f67b5665ac426a3)
#         ;
#
#
#
#
#             var circle_0804b6590f356255877ac57bed8a2f23 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a2c746c232207421608079f5785502e8);
#
#
#         var popup_9b2086af26772bd4a6835aa2d6419418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45fb1f779a88c1bd9047f3c39c7f9db8 = $(`&lt;div id=&quot;html_45fb1f779a88c1bd9047f3c39c7f9db8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_9b2086af26772bd4a6835aa2d6419418.setContent(html_45fb1f779a88c1bd9047f3c39c7f9db8);
#
#
#
#         circle_0804b6590f356255877ac57bed8a2f23.bindPopup(popup_9b2086af26772bd4a6835aa2d6419418)
#         ;
#
#
#
#
#             var circle_8e30e9e349d078bd49156de0970f3a20 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
print('Cost of optimal tour:%f'%m.objVal)
# Out:
# Cost of optimal tour:12695.760679

# %% [markdown]
# ## Nearest neighbor heuristic

# %%
def nearest_neighbor():
    best_tour = []; best_tour_cost = float("inf")
    for i in capitals:
        unvisited = [k for k in capitals if k != i]
        start = i
        tmp_tour = []; tmp_cost = 0
        while len(unvisited) > 0:   
            dist = {k: dist_matrix[k] for k in dist_matrix if k[0] == start and k[1] in unvisited}
            link = min(dist, key=dist.get)
            tmp_tour.append(link)
            tmp_cost += dist[link]
            unvisited.remove(link[1])
            start = link[1]
        tmp_tour.append((link[1], i))
        tmp_cost += dist_matrix[link[1], i]
        if best_tour_cost > tmp_cost:
            best_tour_cost = tmp_cost
            best_tour = tmp_tour
    return best_tour, best_tour_cost

# %%
best_tour, best_tour_cost = nearest_neighbor()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 13791.33048043776
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32c8ee0cbe809d437b4d4d457afc1603 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32c8ee0cbe809d437b4d4d457afc1603&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32c8ee0cbe809d437b4d4d457afc1603 = L.map(
#                 &quot;map_32c8ee0cbe809d437b4d4d457afc1603&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93f69e575d9cbf263a91be198d0590e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_93f69e575d9cbf263a91be198d0590e0.addTo(map_32c8ee0cbe809d437b4d4d457afc1603);
#
#
#             var circle_b8c521688626cf46d89dc33c3085258d = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_32c8ee0cbe809d437b4d4d457afc1603);
#
#
#         var popup_43cefa624c5cc43ed650915a75ef01e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3950ae8828ad80d31f4694735244b1f = $(`&lt;div id=&quot;html_b3950ae8828ad80d31f4694735244b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_43cefa624c5cc43ed650915a75ef01e3.setContent(html_b3950ae8828ad80d31f4694735244b1f);
#
#
#
#         circle_b8c521688626cf46d89dc33c3085258d.bindPopup(popup_43cefa624c5cc43ed650915a75ef01e3)
#         ;
#
#
#
#
#             var circle_524921f7f82885db35173ad55133b235 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_32c8ee0cbe809d437b4d4d457afc1603);
#
#
#         var popup_d8da4f2ab2b52dfd165dbd745d7da433 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5a5270ac3f981bca5044b366f600bfb = $(`&lt;div id=&quot;html_c5a5270ac3f981bca5044b366f600bfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_d8da4f2ab2b52dfd165dbd745d7da433.setContent(html_c5a5270ac3f981bca5044b366f600bfb);
#
#
#
#         circle_524921f7f82885db35173ad55133b235.bindPopup(popup_d8da4f2ab2b52dfd165dbd745d7da433)
#         ;
#
#
#
#
#             var circle_cfd24226caf35cdd58c7b1f4a6b13fc6 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_32c8ee0cbe809d437b4d4d457afc1603);
#
#
#         var popup_5bb9806d7c305b6b03c1d97f710c2933 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25229b0ccda6dea850a28b54fc351d27 = $(`&lt;div id=&quot;html_25229b0ccda6dea850a28b54fc351d27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_5bb9806d7c305b6b03c1d97f710c2933.setContent(html_25229b0ccda6dea850a28b54fc351d27);
#
#
#
#         circle_cfd24226caf35cdd58c7b1f4a6b13fc6.bindPopup(popup_5bb9806d7c305b6b03c1d97f710c2933)
#         ;
#
#
#
#
#             var circle_8c28c797173083ce81878ce1f6b3e087 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Sweep heuristic

# %%
def sweep():
    xcoord = [capitals[k][0] for k in capitals]
    ycoord = [capitals[k][1] for k in capitals]
    centres = []
    
    centres = [(sum(xcoord)/len(capitals) , sum(ycoord)/len(capitals)), (0.5*(max(xcoord) + min(xcoord)), 0.5*(max(ycoord) + min(ycoord)))]
    
    best_tour = []; best_tour_cost = float("inf")
    for xc, yc in centres:
        angle = {} # around the center
        for i in capitals:
            angle[i] = math.degrees(math.atan2(capitals[i][1] - yc, capitals[i][0] - xc))
        angle  = [k for k, v in sorted(angle.items(), key=lambda item: item[1])]
        tour = []; tour_cost = 0
        for k in range(len(angle)):
            if k != 0:
                tour.append((angle[k-1], angle[k]))
                tour_cost += dist_matrix[angle[k-1], angle[k]]
            else:
                start = angle[k]
        tour.append((angle[k], start))
        tour_cost += dist_matrix[(angle[k], start)]
        if tour_cost < best_tour_cost:
            best_tour_cost = tour_cost 
            best_tour = tour
    return best_tour, best_tour_cost
            
best_tour, best_tour_cost = sweep()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 16944.46175833539
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da1e888dca00ba1bee0b96a12c7cd0d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da1e888dca00ba1bee0b96a12c7cd0d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da1e888dca00ba1bee0b96a12c7cd0d5 = L.map(
#                 &quot;map_da1e888dca00ba1bee0b96a12c7cd0d5&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_408fcd1b0fe4ba545d66647a0adf486d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_408fcd1b0fe4ba545d66647a0adf486d.addTo(map_da1e888dca00ba1bee0b96a12c7cd0d5);
#
#
#             var circle_8892e7289eeeb9860924c97ad8a6ccce = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_da1e888dca00ba1bee0b96a12c7cd0d5);
#
#
#         var popup_3e4e846cfbe3ad42e24aa68ca4f321db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_133e6af0c633b85078b24167c01ae134 = $(`&lt;div id=&quot;html_133e6af0c633b85078b24167c01ae134&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_3e4e846cfbe3ad42e24aa68ca4f321db.setContent(html_133e6af0c633b85078b24167c01ae134);
#
#
#
#         circle_8892e7289eeeb9860924c97ad8a6ccce.bindPopup(popup_3e4e846cfbe3ad42e24aa68ca4f321db)
#         ;
#
#
#
#
#             var circle_24b0b5795317e8659cc139ca602695ca = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_da1e888dca00ba1bee0b96a12c7cd0d5);
#
#
#         var popup_ae508cdc93c8fa348c707145d2dbbc91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d83ab6eb452025d303e5dba0d20cf5 = $(`&lt;div id=&quot;html_36d83ab6eb452025d303e5dba0d20cf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_ae508cdc93c8fa348c707145d2dbbc91.setContent(html_36d83ab6eb452025d303e5dba0d20cf5);
#
#
#
#         circle_24b0b5795317e8659cc139ca602695ca.bindPopup(popup_ae508cdc93c8fa348c707145d2dbbc91)
#         ;
#
#
#
#
#             var circle_26c7742412557f9a56d9ed4ed1264aae = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_da1e888dca00ba1bee0b96a12c7cd0d5);
#
#
#         var popup_8a61a79526d39e39cd2d64de7cf437ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc16886c04e87d6e1cfc951efcd7de34 = $(`&lt;div id=&quot;html_cc16886c04e87d6e1cfc951efcd7de34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_8a61a79526d39e39cd2d64de7cf437ae.setContent(html_cc16886c04e87d6e1cfc951efcd7de34);
#
#
#
#         circle_26c7742412557f9a56d9ed4ed1264aae.bindPopup(popup_8a61a79526d39e39cd2d64de7cf437ae)
#         ;
#
#
#
#
#             var circle_d63864ee6fb56fe85f95875f35b6e9a1 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Savings algorithm

# %%
import itertools
start = max(capitals.items(), key=lambda item: (item[1][0], item[1][1]))[0]
unexplored = [k for k in capitals if k != start]
def savings():
    savings = {}
    for k in list(itertools.combinations(capitals, 2)):
        savings[k] = dist_matrix[k[0], start] + dist_matrix[start, k[1]] - dist_matrix[k]
    
    p, q = max(savings, key=savings.get)
    tour = [(p, q)]
    unexplored.remove(p)
    unexplored.remove(q)
    
    while unexplored:
        tmpDict1 = {h: (dist_matrix[p, start] + dist_matrix[start, h] - dist_matrix[p, h], dist_matrix[q, start] + dist_matrix[start, h] - dist_matrix[q, h]) for h in unexplored}
        
        tmpDict2= {}
        for k in tmpDict1:
            if tmpDict1[k][0] > tmpDict1[k][0]:
                tmpDict2[k, p] = tmpDict1[k][0]
            else:
                tmpDict2[k, q] = tmpDict1[k][1]
                
        a, b = max(tmpDict2, key=tmpDict2.get)
        
        if b == p:
            tour.insert(0, (a, p))
        else:
            tour.append((q, a))
        
        p = tour[0][0]
        q = tour[-1][1]
        unexplored.remove(a)
    
    
    
    tour.insert(0, (start, tour[0][0]))
    tour.append((tour[-1][1], start))

    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = savings()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 15118.210264739335
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1d776d681ef5ef72372506642a47d75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1d776d681ef5ef72372506642a47d75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1d776d681ef5ef72372506642a47d75 = L.map(
#                 &quot;map_d1d776d681ef5ef72372506642a47d75&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_128ed7fbae2a2cec2b70e8ff933b85dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_128ed7fbae2a2cec2b70e8ff933b85dd.addTo(map_d1d776d681ef5ef72372506642a47d75);
#
#
#             var circle_44681aa07513796c3f773cd926d20af7 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1d776d681ef5ef72372506642a47d75);
#
#
#         var popup_96455bd110c1913e3b06d328352c9afe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6fceb32160b1e5c0371e3604c0b4a727 = $(`&lt;div id=&quot;html_6fceb32160b1e5c0371e3604c0b4a727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_96455bd110c1913e3b06d328352c9afe.setContent(html_6fceb32160b1e5c0371e3604c0b4a727);
#
#
#
#         circle_44681aa07513796c3f773cd926d20af7.bindPopup(popup_96455bd110c1913e3b06d328352c9afe)
#         ;
#
#
#
#
#             var circle_e45fbabf0a386351756036011936b419 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1d776d681ef5ef72372506642a47d75);
#
#
#         var popup_09ecb65c0cbfbcd078e7bfb8cd2b2585 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38b204e224e8a712804f9f2bd1f6d647 = $(`&lt;div id=&quot;html_38b204e224e8a712804f9f2bd1f6d647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_09ecb65c0cbfbcd078e7bfb8cd2b2585.setContent(html_38b204e224e8a712804f9f2bd1f6d647);
#
#
#
#         circle_e45fbabf0a386351756036011936b419.bindPopup(popup_09ecb65c0cbfbcd078e7bfb8cd2b2585)
#         ;
#
#
#
#
#             var circle_77fcfdcd2efb34792ad8da16c4402d1a = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d1d776d681ef5ef72372506642a47d75);
#
#
#         var popup_6133fd01c4f8a1a8956ed17ac804f421 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5839728f0bcd2e8cbf5fe60ce7e9e9d = $(`&lt;div id=&quot;html_f5839728f0bcd2e8cbf5fe60ce7e9e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_6133fd01c4f8a1a8956ed17ac804f421.setContent(html_f5839728f0bcd2e8cbf5fe60ce7e9e9d);
#
#
#
#         circle_77fcfdcd2efb34792ad8da16c4402d1a.bindPopup(popup_6133fd01c4f8a1a8956ed17ac804f421)
#         ;
#
#
#
#
#             var circle_9d300aaa27fe0ca4817b619a698e2c81 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Cheapest insertion

# %%
def cheapest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    while unexplored:
        point_cost = {}
        for k in unexplored:
            tmpCost = float("inf"); i = 'NA'; j = 'NA'
            for (a, b) in tour:
                if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                    tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                    i = a; j = b
            point_cost[k, (i, j)] = tmpCost
        k, (i,j) = min(point_cost, key=point_cost.get)
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = cheapest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13584.739353336783
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1fffd53183c7543210af8e0ec47ea10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1fffd53183c7543210af8e0ec47ea10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1fffd53183c7543210af8e0ec47ea10 = L.map(
#                 &quot;map_b1fffd53183c7543210af8e0ec47ea10&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbbf2fabfe2513a690eb54ac76a8811c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dbbf2fabfe2513a690eb54ac76a8811c.addTo(map_b1fffd53183c7543210af8e0ec47ea10);
#
#
#             var circle_86648f36a9a92ecf208e873e2b0c00a3 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1fffd53183c7543210af8e0ec47ea10);
#
#
#         var popup_f3b214c51eba446d5c6f855a0e5fed57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_859bac0a279ecfce56dee7dcc8bf8867 = $(`&lt;div id=&quot;html_859bac0a279ecfce56dee7dcc8bf8867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_f3b214c51eba446d5c6f855a0e5fed57.setContent(html_859bac0a279ecfce56dee7dcc8bf8867);
#
#
#
#         circle_86648f36a9a92ecf208e873e2b0c00a3.bindPopup(popup_f3b214c51eba446d5c6f855a0e5fed57)
#         ;
#
#
#
#
#             var circle_5394acc2f09c309f7cca0f0593104b01 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1fffd53183c7543210af8e0ec47ea10);
#
#
#         var popup_f972b3b3c85fd824823eefba4291f314 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb4746df932abedcd7e38f8310140867 = $(`&lt;div id=&quot;html_bb4746df932abedcd7e38f8310140867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_f972b3b3c85fd824823eefba4291f314.setContent(html_bb4746df932abedcd7e38f8310140867);
#
#
#
#         circle_5394acc2f09c309f7cca0f0593104b01.bindPopup(popup_f972b3b3c85fd824823eefba4291f314)
#         ;
#
#
#
#
#             var circle_d927575ed56f7f11a7a2e4ecc153141d = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1fffd53183c7543210af8e0ec47ea10);
#
#
#         var popup_76091dd25cdb4d0854710b3be19d11bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74f7745d8949292b6b494636be484865 = $(`&lt;div id=&quot;html_74f7745d8949292b6b494636be484865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_76091dd25cdb4d0854710b3be19d11bf.setContent(html_74f7745d8949292b6b494636be484865);
#
#
#
#         circle_d927575ed56f7f11a7a2e4ecc153141d.bindPopup(popup_76091dd25cdb4d0854710b3be19d11bf)
#         ;
#
#
#
#
#             var circle_7edca3609833acdf2de651c71a28ccce = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Priciest insertion

# %%
def priciest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    while unexplored:
        point_cost = {}
        for k in unexplored:
            tmpCost = float("inf"); i = 'NA'; j = 'NA'
            for (a, b) in tour:
                if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                    tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                    i = a; j = b
            point_cost[k, (i, j)] = tmpCost
        k, (i,j) = max(point_cost, key=point_cost.get)
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = priciest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13562.587061454724
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ac07bc7f5049566d153b45df9a92466 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ac07bc7f5049566d153b45df9a92466&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ac07bc7f5049566d153b45df9a92466 = L.map(
#                 &quot;map_2ac07bc7f5049566d153b45df9a92466&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8b99aa80f9e95e350667c0fa21ff0d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8b99aa80f9e95e350667c0fa21ff0d6.addTo(map_2ac07bc7f5049566d153b45df9a92466);
#
#
#             var circle_8255c14c23ce3c604f28d2227ab01fa0 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2ac07bc7f5049566d153b45df9a92466);
#
#
#         var popup_3abcfb89b315b72f3ce1d0aa23b518b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_616e0cd8cb0a60285e0cf4b6b0f4bfbc = $(`&lt;div id=&quot;html_616e0cd8cb0a60285e0cf4b6b0f4bfbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_3abcfb89b315b72f3ce1d0aa23b518b4.setContent(html_616e0cd8cb0a60285e0cf4b6b0f4bfbc);
#
#
#
#         circle_8255c14c23ce3c604f28d2227ab01fa0.bindPopup(popup_3abcfb89b315b72f3ce1d0aa23b518b4)
#         ;
#
#
#
#
#             var circle_1057e237f5d29db7fddd70a239176f2b = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2ac07bc7f5049566d153b45df9a92466);
#
#
#         var popup_6f07cb926673d86f30cbbcc3b8306e0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb0c6067fd6d63f3a3e751ad09042a83 = $(`&lt;div id=&quot;html_cb0c6067fd6d63f3a3e751ad09042a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_6f07cb926673d86f30cbbcc3b8306e0e.setContent(html_cb0c6067fd6d63f3a3e751ad09042a83);
#
#
#
#         circle_1057e237f5d29db7fddd70a239176f2b.bindPopup(popup_6f07cb926673d86f30cbbcc3b8306e0e)
#         ;
#
#
#
#
#             var circle_a6f000136c05d4ab3b351677fd8cab14 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2ac07bc7f5049566d153b45df9a92466);
#
#
#         var popup_685790d186a62cdfa890db74d6b84383 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e6e661cd71c2b82f8b85bb0e9384548 = $(`&lt;div id=&quot;html_8e6e661cd71c2b82f8b85bb0e9384548&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_685790d186a62cdfa890db74d6b84383.setContent(html_8e6e661cd71c2b82f8b85bb0e9384548);
#
#
#
#         circle_a6f000136c05d4ab3b351677fd8cab14.bindPopup(popup_685790d186a62cdfa890db74d6b84383)
#         ;
#
#
#
#
#             var circle_18c22a63604f60c76eaec88e965e817f = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## ## Nearest insertion

# %%
def nearest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    explored = [p, q]

    while unexplored:
        point_cost = {(a, b): dist_matrix[a, b] for a in unexplored for b in explored}
        k, j = min(point_cost, key=point_cost.get)
        
        point_cost = {}
       
        tmpCost = float("inf"); i = 'NA'; j = 'NA'
        for (a, b) in tour:
            if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                i = a; j = b
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = nearest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13638.521699122834
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d38324cb3a91e303e8125d983770520 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d38324cb3a91e303e8125d983770520&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d38324cb3a91e303e8125d983770520 = L.map(
#                 &quot;map_2d38324cb3a91e303e8125d983770520&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0b58c9d8cc0535f394a1264f1c02732 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c0b58c9d8cc0535f394a1264f1c02732.addTo(map_2d38324cb3a91e303e8125d983770520);
#
#
#             var circle_77dee22bbc4f42155f1c8a0adaa920e9 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d38324cb3a91e303e8125d983770520);
#
#
#         var popup_1f8b51cec9b0fc685fb5b074c3099815 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7cc1dc5a39a409e28dd53c3c57aabc60 = $(`&lt;div id=&quot;html_7cc1dc5a39a409e28dd53c3c57aabc60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_1f8b51cec9b0fc685fb5b074c3099815.setContent(html_7cc1dc5a39a409e28dd53c3c57aabc60);
#
#
#
#         circle_77dee22bbc4f42155f1c8a0adaa920e9.bindPopup(popup_1f8b51cec9b0fc685fb5b074c3099815)
#         ;
#
#
#
#
#             var circle_214c91e58bc77a86c7756f03f327586c = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d38324cb3a91e303e8125d983770520);
#
#
#         var popup_7b583d70fda80e603d943e062582bf44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a69cec16119742f99323243263f9194a = $(`&lt;div id=&quot;html_a69cec16119742f99323243263f9194a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_7b583d70fda80e603d943e062582bf44.setContent(html_a69cec16119742f99323243263f9194a);
#
#
#
#         circle_214c91e58bc77a86c7756f03f327586c.bindPopup(popup_7b583d70fda80e603d943e062582bf44)
#         ;
#
#
#
#
#             var circle_6ae93ac0125713dac352d8dc38a23477 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2d38324cb3a91e303e8125d983770520);
#
#
#         var popup_79fcd9a867da83b77fc0f5140bc67c53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_091070ccb27466bb88a18228769e1fe1 = $(`&lt;div id=&quot;html_091070ccb27466bb88a18228769e1fe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_79fcd9a867da83b77fc0f5140bc67c53.setContent(html_091070ccb27466bb88a18228769e1fe1);
#
#
#
#         circle_6ae93ac0125713dac352d8dc38a23477.bindPopup(popup_79fcd9a867da83b77fc0f5140bc67c53)
#         ;
#
#
#
#
#             var circle_8a2dff749faa99f7c8fdce07ef238e49 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Farthest insertion

# %%
def farthest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    explored = [p, q]

    while unexplored:
        tmp2 = -float("inf"); k = 'NA'
        for a in unexplored:
            tmp1 = float("inf"); j = 'NA'
            for b in explored:
                if tmp1 > dist_matrix[a, b]:
                    tmp1 = dist_matrix[a, b]; j = b
            if tmp2 < tmp1:
                tmp2 = tmp1; k = a
                
        
       
        tmpCost = float("inf"); i = 'NA'; j = 'NA'
        for (a, b) in tour:
            if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                i = a; j = b
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = farthest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13548.288647195177
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7db288a5ce90ad61416bcda4e37a42cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7db288a5ce90ad61416bcda4e37a42cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7db288a5ce90ad61416bcda4e37a42cf = L.map(
#                 &quot;map_7db288a5ce90ad61416bcda4e37a42cf&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aceca12afb30b81547b6b2ffe30db820 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aceca12afb30b81547b6b2ffe30db820.addTo(map_7db288a5ce90ad61416bcda4e37a42cf);
#
#
#             var circle_cd7e688150c52c7b95b3ec85de442064 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7db288a5ce90ad61416bcda4e37a42cf);
#
#
#         var popup_c3627276d4bf4e49334ceab71e39b5c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09326e9069e5685d25ea70be90ea9c8e = $(`&lt;div id=&quot;html_09326e9069e5685d25ea70be90ea9c8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_c3627276d4bf4e49334ceab71e39b5c5.setContent(html_09326e9069e5685d25ea70be90ea9c8e);
#
#
#
#         circle_cd7e688150c52c7b95b3ec85de442064.bindPopup(popup_c3627276d4bf4e49334ceab71e39b5c5)
#         ;
#
#
#
#
#             var circle_f93b95d8c0b681addd5426d3c7059d5d = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7db288a5ce90ad61416bcda4e37a42cf);
#
#
#         var popup_47bdcd5be3bbf132974a99f46a534799 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a382df11b7638b6544c1796e0d054b87 = $(`&lt;div id=&quot;html_a382df11b7638b6544c1796e0d054b87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_47bdcd5be3bbf132974a99f46a534799.setContent(html_a382df11b7638b6544c1796e0d054b87);
#
#
#
#         circle_f93b95d8c0b681addd5426d3c7059d5d.bindPopup(popup_47bdcd5be3bbf132974a99f46a534799)
#         ;
#
#
#
#
#             var circle_b26ec85e9f15dd3e1483caa920f0bd40 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7db288a5ce90ad61416bcda4e37a42cf);
#
#
#         var popup_10048f549f16476a74db2d18f6824a2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fb5298ee623e564ca35468add278ad6 = $(`&lt;div id=&quot;html_9fb5298ee623e564ca35468add278ad6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_10048f549f16476a74db2d18f6824a2e.setContent(html_9fb5298ee623e564ca35468add278ad6);
#
#
#
#         circle_b26ec85e9f15dd3e1483caa920f0bd40.bindPopup(popup_10048f549f16476a74db2d18f6824a2e)
#         ;
#
#
#
#
#             var circle_94cb09da2e5ada5dff85a11154c5ebab = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo
