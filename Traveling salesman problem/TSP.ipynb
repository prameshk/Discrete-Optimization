# %% [markdown]
# # Around the world in X number of days using Traveling Salesman Problem (TSP)

# %% [markdown]
# In this tutorial, we will learn how to exactly and heuristically solve TSP.

# %%
# Copyright 2020, Gurobi Optimization, LLC
import csv, time, math, random  
from gurobipy import * 
import networkx as nx # For drawing tours and subtours
from haversine import haversine, Unit # For computing the haversine distance

# %% [markdown]
# ### Reading data

# %%
capitals = {} # Dictionary of capitals with values as coordinates
with open('coord_ind_cap.csv', newline='') as csvfile:
    reader = csv.reader(csvfile) # reader
    next(reader) # skip header
    for row in reader:
        capitals[row[1], row[0]] = (float(row[2]), float(row[3]))

dist_matrix = {}
for c1 in capitals:
    for c2 in capitals:
        dist_matrix[c1, c2] = haversine(capitals[c1], capitals[c2], unit=Unit.KILOMETERS) # computes the haversine distance between two coordinates

neighbors = {i:[] for i in capitals} # Adjacency dictionary

for i, j in dist_matrix:
    if j not in neighbors[i]:
        neighbors[i].append(j)
    if i not in neighbors[j]:
        neighbors[j].append(i)

# %%
# Drawing on the map
# Drawing the tour/subtour
import folium # Library for creating the maps
def draw_tour(edges):     
    # The averate coordinate will be used for setting up the initial map
    average_lat = sum(lat for lat, lon in capitals.values()) / len(capitals)
    average_lon = sum(lon for lat, lon in capitals.values()) / len(capitals)
    
    # Intialize the map with location of the center of the map and zoom level
    mymap = folium.Map(location=[average_lat, average_lon], zoom_start=4)
    
    # We put a small circle at each capital.   
    for c in capitals:
        folium.Circle([capitals[c][0], capitals[c][1]],radius=2000, color='red', fill=True, fill_color='red', 
                      fill_opacity=0.7,popup=c).add_to(mymap)

    # We put edges between coordinates
    for i, j in edges:
        coord1 = (capitals[i][0], capitals[i][1])
        coord2 = (capitals[j][0], capitals[j][1])
        folium.PolyLine([coord1, coord2], color="blue", weight=2.5, opacity=1).add_to(mymap)
        
    return mymap

# %% [markdown]
# ### MTZ model

# %%
m = Model() # Initialize the model

# Define decision variables
x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals} # Whether an edge is part of tour or not
u = {i: m.addVar(vtype=GRB.INTEGER) for i in capitals} # Order in which each capital is visited

# Add constraints
for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if i != j]) == 1) 
    m.addConstr(sum([x[j, i] for j in capitals if i != j]) == 1)

# Without loss of generality, let's assume the first city is the first capital in the list
first = list(capitals.keys())[0]

m.addConstr(u[first] == 1) # The order for first city is 1


for i in capitals:
    if i != first:
        m.addConstr(u[i] <= len(capitals)) # Order should be less than the number of cities
        m.addConstr(u[i] >= 2)

for i, j in dist_matrix:
    if i != first and j != first:
        m.addConstr(u[i] - u[j] + 1 <= (len(capitals) - 1) * (1 - x[i, j])) # Subtour elimination


obj = sum([dist_matrix[k] * x[k] for k in dist_matrix]) # Total cost of tour
m.setObjective(obj, sense=GRB.MINIMIZE)
m.optimize()
print(m.status)
edges  = [k for k in x if x[k].x > 0.4] # Edges in the optimal tour
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-12
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 1224 rows, 1190 columns and 5512 nonzeros
# Model fingerprint: 0xf0524df0
# Variable types: 0 continuous, 1190 integer (1156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 100 rows and 35 columns
# Presolve time: 0.01s
# Presolved: 1124 rows, 1155 columns, 5412 nonzeros
# Variable types: 0 continuous, 1155 integer (1122 binary)
# Found heuristic solution: objective 48270.923208
#
# Root relaxation: objective 1.137562e+04, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11375.6174    0   58 48270.9232 11375.6174  76.4%     -    0s
# H    0     0                    15983.567037 11375.6174  28.8%     -    0s
# H    0     0                    15870.553295 11375.6174  28.3%     -    0s
#      0     0 12132.8050    0   76 15870.5533 12132.8050  23.6%     -    0s
#      0     0 12132.8050    0   76 15870.5533 12132.8050  23.6%     -    0s
# H    0     0                    15714.680051 12160.7217  22.6%     -    0s
#      0     0 12195.2862    0   64 15714.6801 12195.2862  22.4%     -    0s
#      0     0 12195.2862    0   63 15714.6801 12195.2862  22.4%     -    0s
# H    0     0                    14430.001138 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   61 14430.0011 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   59 14430.0011 12195.2862  15.5%     -    0s
#      0     0 12195.2862    0   40 14430.0011 12195.2862  15.5%     -    0s
# H    0     0                    13981.440418 12195.2862  12.8%     -    0s
#      0     0 12223.4413    0   47 13981.4404 12223.4413  12.6%     -    0s
#      0     0 12223.4413    0   52 13981.4404 12223.4413  12.6%     -    0s
#      0     0 12223.4413    0   49 13981.4404 12223.4413  12.6%     -    0s
# H    0     0                    13605.013822 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   59 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   68 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   63 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   87 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   92 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12223.4413    0   96 13605.0138 12223.4413  10.2%     -    0s
#      0     0 12238.8407    0   99 13605.0138 12238.8407  10.0%     -    0s
#      0     0 12244.4290    0   90 13605.0138 12244.4290  10.0%     -    0s
#      0     0 12245.4035    0   92 13605.0138 12245.4035  10.0%     -    0s
#      0     0 12245.4035    0   88 13605.0138 12245.4035  10.0%     -    0s
#      0     0 12249.8106    0   90 13605.0138 12249.8106  10.0%     -    0s
# H    0     0                    13414.350579 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   89 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   92 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   39 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   60 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   49 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   49 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   46 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12249.8106    0   42 13414.3506 12249.8106  8.68%     -    0s
#      0     0 12255.8990    0   61 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   76 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   90 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   88 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   89 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12255.8990    0   88 13414.3506 12255.8990  8.64%     -    0s
#      0     0 12269.5062    0   85 13414.3506 12269.5062  8.53%     -    0s
#      0     0 12275.6888    0   69 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   69 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   73 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     0 12275.6888    0   80 13414.3506 12275.6888  8.49%     -    0s
#      0     2 12276.8600    0   80 13414.3506 12276.8600  8.48%     -    0s
# H  119   128                    13325.452108 12280.3723  7.84%  15.6    1s
# H  175   202                    13170.721334 12280.3723  6.76%  13.5    1s
# H  182   202                    13095.327926 12280.3723  6.22%  13.5    1s
# H 1515  1178                    13011.008213 12280.3723  5.62%   8.8    1s
# H 2763  1801                    12941.570242 12294.6459  5.00%   9.6    1s
# H 2807  1759                    12922.738393 12294.6459  4.86%   9.9    2s
# H 2812  1675                    12894.123079 12294.6459  4.65%  10.0    2s
# H 4565  2020                    12892.106846 12296.3816  4.62%  10.1    2s
# *14351  5131              36    12771.361266 12351.8152  3.29%   9.3    3s
# H27657  6643                    12695.760679 12470.6006  1.77%   9.2    4s
#  31298  6731 12614.7445   21   96 12695.7607 12486.7422  1.65%   9.3    5s
#
# Cutting planes:
#   Learned: 19
#   Gomory: 79
#   Lift-and-project: 2
#   Cover: 17
#   Implied bound: 15
#   Projected implied bound: 10
#   MIR: 63
#   StrongCG: 3
#   Flow cover: 201
#   Inf proof: 20
#   Zero half: 22
#   RLT: 28
#   Relax-and-lift: 39
#
# Explored 44529 nodes (455601 simplex iterations) in 6.86 seconds (3.97 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 10: 12695.8 12771.4 12892.1 ... 13325.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%
# 2

# %%
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96474617280b012a8d78c120ff63f68c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96474617280b012a8d78c120ff63f68c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96474617280b012a8d78c120ff63f68c = L.map(
#                 &quot;map_96474617280b012a8d78c120ff63f68c&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78dfbc2bb34a033fd55877a565d11bcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_78dfbc2bb34a033fd55877a565d11bcc.addTo(map_96474617280b012a8d78c120ff63f68c);
#
#
#             var circle_bde56130f60fc700bcf76ec0d4b33560 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96474617280b012a8d78c120ff63f68c);
#
#
#         var popup_7969d7fc888e5889b51845c0b8426dde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09e371f2a4a3985c0c26c6b86b9a78f8 = $(`&lt;div id=&quot;html_09e371f2a4a3985c0c26c6b86b9a78f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_7969d7fc888e5889b51845c0b8426dde.setContent(html_09e371f2a4a3985c0c26c6b86b9a78f8);
#
#
#
#         circle_bde56130f60fc700bcf76ec0d4b33560.bindPopup(popup_7969d7fc888e5889b51845c0b8426dde)
#         ;
#
#
#
#
#             var circle_7c17004e81aa1b5dd0e27ee25492eecb = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96474617280b012a8d78c120ff63f68c);
#
#
#         var popup_f8d4f158771dbc4c604d5aed0596fd35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b256474ca9cd32ad6a6b7e17b951639 = $(`&lt;div id=&quot;html_9b256474ca9cd32ad6a6b7e17b951639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_f8d4f158771dbc4c604d5aed0596fd35.setContent(html_9b256474ca9cd32ad6a6b7e17b951639);
#
#
#
#         circle_7c17004e81aa1b5dd0e27ee25492eecb.bindPopup(popup_f8d4f158771dbc4c604d5aed0596fd35)
#         ;
#
#
#
#
#             var circle_e9638da473d8331b5993abb3cc6c593a = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_96474617280b012a8d78c120ff63f68c);
#
#
#         var popup_6afa0ada7afea617e05d6657caeb2aba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9454d90aee7c6ca73f245986860fd0e2 = $(`&lt;div id=&quot;html_9454d90aee7c6ca73f245986860fd0e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_6afa0ada7afea617e05d6657caeb2aba.setContent(html_9454d90aee7c6ca73f245986860fd0e2);
#
#
#
#         circle_e9638da473d8331b5993abb3cc6c593a.bindPopup(popup_6afa0ada7afea617e05d6657caeb2aba)
#         ;
#
#
#
#
#             var circle_490eff9d202c48099a9fb54e6ee6bebe = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ### Formulation with alternative subtour constraints

# %%
m = Model()
x = {(i, j): m.addVar(vtype = GRB.BINARY, name = f'x_{i},{j}') for i in capitals for j in capitals}
q = {(i, j): m.addVar(vtype = GRB.CONTINUOUS, name=f'q_{i},{j}') for i in capitals for j in capitals}

for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if j != i]) == 1)
    m.addConstr(sum([x[j, i] for j in capitals if j != i]) == 1)

first = list(capitals.keys())[0]

m.addConstr(sum([q[first, j] for j in capitals]) == len(capitals), name = 'len')
m.addConstr(sum([q[j, first] for j in capitals]) == 1, name = 'first')

for i in capitals:
    if i != first:
        m.addConstr(sum([q[j, i] for j in capitals if j != i]) - sum([q[i, j] for j in capitals if j != i]) == 1, name = f'cons_{i}')

for i in capitals:
    for j in capitals:
        if i != j:
            m.addConstr(q[i,j] <= (len(capitals) + 2) * x[i, j])

obj = sum([dist_matrix[k] * x[k] for k in dist_matrix])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.optimize()
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 1225 rows, 2312 columns and 6734 nonzeros
# Model fingerprint: 0x3b11d716
# Variable types: 1156 continuous, 1156 integer (1156 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+01]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 0 rows and 67 columns
# Presolve time: 0.02s
# Presolved: 1225 rows, 2245 columns, 6734 nonzeros
# Variable types: 1123 continuous, 1122 integer (1122 binary)
# Found heuristic solution: objective 62866.638909
# Found heuristic solution: objective 38930.395746
#
# Root relaxation: objective 1.168296e+04, 1937 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11682.9644    0   57 38930.3957 11682.9644  70.0%     -    0s
# H    0     0                    16209.714216 11682.9644  27.9%     -    0s
# H    0     0                    13683.226515 11682.9644  14.6%     -    0s
#      0     0 12429.1689    0   77 13683.2265 12429.1689  9.16%     -    0s
# H    0     0                    13458.514337 12429.1689  7.65%     -    0s
#      0     0 12526.0570    0   67 13458.5143 12526.0570  6.93%     -    0s
#      0     0 12526.0570    0   67 13458.5143 12526.0570  6.93%     -    0s
#      0     0 12662.6050    0   75 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   55 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   72 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   27 13458.5143 12662.6050  5.91%     -    0s
#      0     0 12662.6050    0   27 13458.5143 12662.6050  5.91%     -    0s
# H    0     0                    13368.271691 12662.6050  5.28%     -    0s
# *    0     0               0    12695.760679 12695.7607  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 7
#   Lift-and-project: 7
#   Implied bound: 29
#   MIR: 12
#   Flow cover: 34
#   Flow path: 10
#   Network: 14
#
# Explored 1 nodes (4414 simplex iterations) in 0.40 seconds (0.27 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 7: 12695.8 13368.3 13458.5 ... 62866.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%

# %%
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d9249c6471331683756940f0eaf4e7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d9249c6471331683756940f0eaf4e7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d9249c6471331683756940f0eaf4e7c = L.map(
#                 &quot;map_8d9249c6471331683756940f0eaf4e7c&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_881dcdf3261fd1e356fb3fd15760cb5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_881dcdf3261fd1e356fb3fd15760cb5b.addTo(map_8d9249c6471331683756940f0eaf4e7c);
#
#
#             var circle_8e521325682ef5bab23c20977acf23b0 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d9249c6471331683756940f0eaf4e7c);
#
#
#         var popup_c0173aaab94207047d08af17e1bbbbed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_132eb0636e320da2aea8aa147ffa5299 = $(`&lt;div id=&quot;html_132eb0636e320da2aea8aa147ffa5299&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_c0173aaab94207047d08af17e1bbbbed.setContent(html_132eb0636e320da2aea8aa147ffa5299);
#
#
#
#         circle_8e521325682ef5bab23c20977acf23b0.bindPopup(popup_c0173aaab94207047d08af17e1bbbbed)
#         ;
#
#
#
#
#             var circle_063b90d588dcee955dc64a285b8e5785 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d9249c6471331683756940f0eaf4e7c);
#
#
#         var popup_e88429a02a7f164c0dd56b4274d2e1ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a69860dfc106cd9cfaf9814741d7a782 = $(`&lt;div id=&quot;html_a69860dfc106cd9cfaf9814741d7a782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_e88429a02a7f164c0dd56b4274d2e1ed.setContent(html_a69860dfc106cd9cfaf9814741d7a782);
#
#
#
#         circle_063b90d588dcee955dc64a285b8e5785.bindPopup(popup_e88429a02a7f164c0dd56b4274d2e1ed)
#         ;
#
#
#
#
#             var circle_c7bc76667cf551315780b25d6fdf46d0 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d9249c6471331683756940f0eaf4e7c);
#
#
#         var popup_6abc370fa32968f5a192a0bf8e76c98c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f9d99c56effb73f808433378285ef0f = $(`&lt;div id=&quot;html_4f9d99c56effb73f808433378285ef0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_6abc370fa32968f5a192a0bf8e76c98c.setContent(html_4f9d99c56effb73f808433378285ef0f);
#
#
#
#         circle_c7bc76667cf551315780b25d6fdf46d0.bindPopup(popup_6abc370fa32968f5a192a0bf8e76c98c)
#         ;
#
#
#
#
#             var circle_8ea690c1bfd4408abb0ea972e2ed7f81 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## DFJ

# %%
from itertools import combinations # for obtaining subsets

m = Model()
x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals if i != j}

for i in capitals:
    m.addConstr(sum([x[i, j] for j in capitals if i != j]) == 1)
    m.addConstr(sum([x[j, i] for j in capitals if i != j]) == 1)


obj = sum([dist_matrix[k] * x[k] for k in dist_matrix if k[0] != k[1]])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.Params.OutputFlag = 0

# %%
m.optimize()

# %%
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c54e2aa19c531034a63f8688c6889327 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c54e2aa19c531034a63f8688c6889327&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c54e2aa19c531034a63f8688c6889327 = L.map(
#                 &quot;map_c54e2aa19c531034a63f8688c6889327&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fea460279246756263bbe8dedec300eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fea460279246756263bbe8dedec300eb.addTo(map_c54e2aa19c531034a63f8688c6889327);
#
#
#             var circle_9373795b0bd337393f24bfdc803163fe = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c54e2aa19c531034a63f8688c6889327);
#
#
#         var popup_8e56cbe2faf46b41f84ae972d12d5cc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf9c932bce00614e0af605a14ada56da = $(`&lt;div id=&quot;html_bf9c932bce00614e0af605a14ada56da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_8e56cbe2faf46b41f84ae972d12d5cc9.setContent(html_bf9c932bce00614e0af605a14ada56da);
#
#
#
#         circle_9373795b0bd337393f24bfdc803163fe.bindPopup(popup_8e56cbe2faf46b41f84ae972d12d5cc9)
#         ;
#
#
#
#
#             var circle_38220777525247aac9c531c494dac2cf = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c54e2aa19c531034a63f8688c6889327);
#
#
#         var popup_2aaf8a626711ff5886671a2af1d695e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa8064c85c983bc345ee86f576c543c0 = $(`&lt;div id=&quot;html_aa8064c85c983bc345ee86f576c543c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_2aaf8a626711ff5886671a2af1d695e0.setContent(html_aa8064c85c983bc345ee86f576c543c0);
#
#
#
#         circle_38220777525247aac9c531c494dac2cf.bindPopup(popup_2aaf8a626711ff5886671a2af1d695e0)
#         ;
#
#
#
#
#             var circle_2d266fe0701c1f54711c31b0f22386da = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c54e2aa19c531034a63f8688c6889327);
#
#
#         var popup_16176d4879c5676c687f9b8f769092ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2d63daa276ef8cb4c9d06916bcd2849 = $(`&lt;div id=&quot;html_a2d63daa276ef8cb4c9d06916bcd2849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_16176d4879c5676c687f9b8f769092ec.setContent(html_a2d63daa276ef8cb4c9d06916bcd2849);
#
#
#
#         circle_2d266fe0701c1f54711c31b0f22386da.bindPopup(popup_16176d4879c5676c687f9b8f769092ec)
#         ;
#
#
#
#
#             var circle_216a2994da1405c296bff2d59d6707b6 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
def find_subtours(edges):
    subtours = []
    while edges:
        (i, j) = edges.pop(0)
        visited = [i, j]
        stop = False
        while not stop:
            neighbors = [k for k in edges if k[0] == j]
            if neighbors[0][1] in visited:
                visited.append(neighbors[0][1])
                edges.remove(neighbors[0])
                subtours.append(visited)
                stop = True
            else:
                visited.append(neighbors[0][1])
                (i, j) = neighbors[0]
                edges.remove(neighbors[0])
    return subtours
iterations = 0

# %% [markdown]
# ### We repeatedly add subtour elimination constraints until we get a tour

# %%
subtours = find_subtours(edges)

for s in subtours:
    tmp = 0; edge_count = 0
    for n in range(len(s)):
        if n != 0:
            tmp += x[s[n-1], s[n]]
            edge_count += 1
    m.addConstr(tmp <= edge_count - 1)

m.update()
m.optimize()
edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
subtours = find_subtours(edges)
iterations +=1 
print(iterations)


edges  = [k for k in x if x[k].x > 0.4]
draw_tour(edges)
# Out:
# 1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7ea5bc7931f5e3f4ea27f54d484f650 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7ea5bc7931f5e3f4ea27f54d484f650&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7ea5bc7931f5e3f4ea27f54d484f650 = L.map(
#                 &quot;map_f7ea5bc7931f5e3f4ea27f54d484f650&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_598f04a41fb9c5390daeb548f67c4fd5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_598f04a41fb9c5390daeb548f67c4fd5.addTo(map_f7ea5bc7931f5e3f4ea27f54d484f650);
#
#
#             var circle_0bfcd0747b404484a07d485406e7525f = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7ea5bc7931f5e3f4ea27f54d484f650);
#
#
#         var popup_eac733d02a24afff1741079b90f3ee1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e29197d97823c2ded52ea86cfcb3bb01 = $(`&lt;div id=&quot;html_e29197d97823c2ded52ea86cfcb3bb01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_eac733d02a24afff1741079b90f3ee1c.setContent(html_e29197d97823c2ded52ea86cfcb3bb01);
#
#
#
#         circle_0bfcd0747b404484a07d485406e7525f.bindPopup(popup_eac733d02a24afff1741079b90f3ee1c)
#         ;
#
#
#
#
#             var circle_e40874606431563154cf8a8b0cebf310 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7ea5bc7931f5e3f4ea27f54d484f650);
#
#
#         var popup_663e5f782b8ded63d6fe8b9dd1c7861f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd189f2e888571326444d6083ad6d133 = $(`&lt;div id=&quot;html_bd189f2e888571326444d6083ad6d133&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_663e5f782b8ded63d6fe8b9dd1c7861f.setContent(html_bd189f2e888571326444d6083ad6d133);
#
#
#
#         circle_e40874606431563154cf8a8b0cebf310.bindPopup(popup_663e5f782b8ded63d6fe8b9dd1c7861f)
#         ;
#
#
#
#
#             var circle_eb41332da9047057907801ddd2ea9fb2 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7ea5bc7931f5e3f4ea27f54d484f650);
#
#
#         var popup_89ac51d6853cbf8fa63391b5f45dd9ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52efec0568e66bda5f78dfb2b4109f1f = $(`&lt;div id=&quot;html_52efec0568e66bda5f78dfb2b4109f1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_89ac51d6853cbf8fa63391b5f45dd9ff.setContent(html_52efec0568e66bda5f78dfb2b4109f1f);
#
#
#
#         circle_eb41332da9047057907801ddd2ea9fb2.bindPopup(popup_89ac51d6853cbf8fa63391b5f45dd9ff)
#         ;
#
#
#
#
#             var circle_2fe39dd836cc17fffdbcd105af79802a = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
print('TSP solved in %d iterations'%iterations)
print('cost of the tour is: %f'%m.objVal)
# Out:
# TSP solved in 1 iterations
# cost of the tour is: 12441.559642

# %% [markdown]
# #### To sutomate this process, we route a subroutine "subtourelim" and pass it in a callback function. This is how you implement a version of branch-and-cut

# %%
# Callback - use lazy constraints to eliminate sub-tours
def subtourelim(model, where):

    if where == GRB.Callback.MIPSOL:
        vals = model.cbGetSolution(model._x) 

        
        
        edges  = [k for k in m._x if vals[k] > 0.4]
        subtours = find_subtours(edges)
        print('It: %d and # subtours: %d'%(m._iterations, len(subtours)))
        if len(subtours) > 1:
            for s in subtours:
                tmp = 0; edge_count = 0
                for n in range(len(s)):
                    if n != 0:
                        tmp += model._x[s[n-1], s[n]]
                        edge_count += 1
            
                model.cbLazy(tmp <= edge_count - 1)
            
            
        model._iterations += 1

# %%
m = Model()
m._x = {(i, j): m.addVar(vtype = GRB.BINARY) for i in capitals for j in capitals if i != j}
m._iterations = 0
for i in capitals:
    m.addConstr(sum([m._x[i, j] for j in capitals if i != j]) == 1)
    m.addConstr(sum([m._x[j, i] for j in capitals if i != j]) == 1)


obj = sum([dist_matrix[k] * m._x[k] for k in dist_matrix if k[0] != k[1]])
m.setObjective(obj, sense=GRB.MINIMIZE)
m.Params.lazyConstraints = 1
m.optimize(subtourelim)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 68 rows, 1122 columns and 2244 nonzeros
# Model fingerprint: 0xa14f37ca
# Variable types: 0 continuous, 1122 integer (1122 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# It: 0 and # subtours: 2
# Presolve time: 0.00s
# Presolved: 68 rows, 1122 columns, 2244 nonzeros
# Variable types: 0 continuous, 1122 integer (1122 binary)
# It: 1 and # subtours: 16
# It: 2 and # subtours: 17
#
# Root relaxation: objective 1.227256e+04, 106 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12272.5573    0   30          - 12272.5573      -     -    0s
# It: 3 and # subtours: 10
# It: 4 and # subtours: 6
# It: 5 and # subtours: 10
# It: 6 and # subtours: 6
#      0     0 12432.9131    0   52          - 12432.9131      -     -    0s
# It: 7 and # subtours: 4
#      0     2 12432.9131    0   52          - 12432.9131      -     -    0s
# It: 8 and # subtours: 3
# It: 9 and # subtours: 7
# It: 10 and # subtours: 2
# It: 11 and # subtours: 4
# It: 12 and # subtours: 4
# It: 13 and # subtours: 3
# It: 14 and # subtours: 4
# It: 15 and # subtours: 4
# It: 16 and # subtours: 5
# It: 17 and # subtours: 6
# It: 18 and # subtours: 3
# It: 19 and # subtours: 3
# It: 20 and # subtours: 4
# It: 21 and # subtours: 4
# It: 22 and # subtours: 3
# It: 23 and # subtours: 3
# It: 24 and # subtours: 3
# It: 25 and # subtours: 3
# It: 26 and # subtours: 4
# It: 27 and # subtours: 4
# It: 28 and # subtours: 4
# It: 29 and # subtours: 4
# It: 30 and # subtours: 4
# It: 31 and # subtours: 3
# It: 32 and # subtours: 2
# It: 33 and # subtours: 1
# H  588   560                    17880.142765 12498.8992  30.1%   5.4    0s
# It: 34 and # subtours: 3
# It: 35 and # subtours: 3
# It: 36 and # subtours: 3
# It: 37 and # subtours: 3
# It: 38 and # subtours: 2
# It: 39 and # subtours: 3
# It: 40 and # subtours: 3
# It: 41 and # subtours: 3
# It: 42 and # subtours: 3
# It: 43 and # subtours: 1
# *  835   838              27    13928.113794 12498.8992  10.3%   5.2    0s
# It: 44 and # subtours: 2
# It: 45 and # subtours: 5
# It: 46 and # subtours: 3
# It: 47 and # subtours: 1
# *  945   965              36    13086.948748 12505.4103  4.44%   5.1    0s
# It: 48 and # subtours: 2
# It: 49 and # subtours: 2
# It: 50 and # subtours: 3
# It: 51 and # subtours: 2
# It: 52 and # subtours: 1
# * 1272  1104              17    12770.158936 12505.4103  2.07%   4.8    0s
# It: 53 and # subtours: 2
# It: 54 and # subtours: 1
# * 1333  1106              17    12732.830874 12505.4103  1.79%   4.7    0s
# It: 55 and # subtours: 1
# * 1436  1129              17    12711.632015 12505.4103  1.62%   4.6    0s
# It: 56 and # subtours: 2
# It: 57 and # subtours: 3
# It: 58 and # subtours: 1
# H 1656  1132                    12701.849059 12505.4103  1.55%   4.6    0s
# It: 59 and # subtours: 2
# It: 60 and # subtours: 1
# * 2129  1164              15    12695.760679 12532.4471  1.29%   4.6    0s
# It: 61 and # subtours: 2
#
# Cutting planes:
#   Cover: 2
#   Lazy constraints: 218
#
# Explored 4231 nodes (16835 simplex iterations) in 0.32 seconds (0.13 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 8: 12695.8 12701.8 12711.6 ... 17880.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.269576067876e+04, best bound 1.269576067876e+04, gap 0.0000%
#
# User-callback calls 8668, time in user-callback 0.04 sec

# %%
edges  = [k for k in m._x if m._x[k].x > 0.4]
draw_tour(edges)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1571c46c94afceaef912164e63c0d013 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1571c46c94afceaef912164e63c0d013&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1571c46c94afceaef912164e63c0d013 = L.map(
#                 &quot;map_1571c46c94afceaef912164e63c0d013&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5192bbd53bb1ea908e2c76039bfb0f79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5192bbd53bb1ea908e2c76039bfb0f79.addTo(map_1571c46c94afceaef912164e63c0d013);
#
#
#             var circle_922ed4613165c23d24ce8a018d10289d = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1571c46c94afceaef912164e63c0d013);
#
#
#         var popup_f641b4aad0e5c125154e7fac18363cc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59b8e37283b9a2cbcc5eb2d64aa4dcce = $(`&lt;div id=&quot;html_59b8e37283b9a2cbcc5eb2d64aa4dcce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_f641b4aad0e5c125154e7fac18363cc6.setContent(html_59b8e37283b9a2cbcc5eb2d64aa4dcce);
#
#
#
#         circle_922ed4613165c23d24ce8a018d10289d.bindPopup(popup_f641b4aad0e5c125154e7fac18363cc6)
#         ;
#
#
#
#
#             var circle_269153cb92d4ce4ed13a50c4c9263d46 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1571c46c94afceaef912164e63c0d013);
#
#
#         var popup_f1bb561f11ff43287d78b7ef94af54df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_874126a75ac324fe203b03e7e2c7d3f4 = $(`&lt;div id=&quot;html_874126a75ac324fe203b03e7e2c7d3f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_f1bb561f11ff43287d78b7ef94af54df.setContent(html_874126a75ac324fe203b03e7e2c7d3f4);
#
#
#
#         circle_269153cb92d4ce4ed13a50c4c9263d46.bindPopup(popup_f1bb561f11ff43287d78b7ef94af54df)
#         ;
#
#
#
#
#             var circle_b53d5a6a82384dfcfd28a1011fc0a6d5 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1571c46c94afceaef912164e63c0d013);
#
#
#         var popup_1e6273fd7b64b1cc674e64d637056fd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7ee088db30b3f0ae93c30aab6ef2e3d = $(`&lt;div id=&quot;html_b7ee088db30b3f0ae93c30aab6ef2e3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_1e6273fd7b64b1cc674e64d637056fd1.setContent(html_b7ee088db30b3f0ae93c30aab6ef2e3d);
#
#
#
#         circle_b53d5a6a82384dfcfd28a1011fc0a6d5.bindPopup(popup_1e6273fd7b64b1cc674e64d637056fd1)
#         ;
#
#
#
#
#             var circle_ebbf286a41ebccdc4f2f6b4b4c2e020b = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
print('Cost of optimal tour:%f'%m.objVal)
# Out:
# Cost of optimal tour:12695.760679

# %% [markdown]
# ## Nearest neighbor heuristic

# %%
def nearest_neighbor():
    best_tour = []; best_tour_cost = float("inf")
    for i in capitals:
        unvisited = [k for k in capitals if k != i]
        start = i
        tmp_tour = []; tmp_cost = 0
        while len(unvisited) > 0:   
            dist = {k: dist_matrix[k] for k in dist_matrix if k[0] == start and k[1] in unvisited}
            link = min(dist, key=dist.get)
            tmp_tour.append(link)
            tmp_cost += dist[link]
            unvisited.remove(link[1])
            start = link[1]
        tmp_tour.append((link[1], i))
        tmp_cost += dist_matrix[link[1], i]
        if best_tour_cost > tmp_cost:
            best_tour_cost = tmp_cost
            best_tour = tmp_tour
    return best_tour, best_tour_cost

# %%
best_tour, best_tour_cost = nearest_neighbor()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 13791.33048043776
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdd31a025e1a2d4a1ef37f8f8868064a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdd31a025e1a2d4a1ef37f8f8868064a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdd31a025e1a2d4a1ef37f8f8868064a = L.map(
#                 &quot;map_bdd31a025e1a2d4a1ef37f8f8868064a&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66c77e5c6be7e70fbb2ebda564e15d52 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_66c77e5c6be7e70fbb2ebda564e15d52.addTo(map_bdd31a025e1a2d4a1ef37f8f8868064a);
#
#
#             var circle_112d8809a1637c7379fdb64eaf69c1ba = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bdd31a025e1a2d4a1ef37f8f8868064a);
#
#
#         var popup_18f0796c02000bf6a84d738a844c539c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1496c5ce0843387ad6bd52661d60fb58 = $(`&lt;div id=&quot;html_1496c5ce0843387ad6bd52661d60fb58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_18f0796c02000bf6a84d738a844c539c.setContent(html_1496c5ce0843387ad6bd52661d60fb58);
#
#
#
#         circle_112d8809a1637c7379fdb64eaf69c1ba.bindPopup(popup_18f0796c02000bf6a84d738a844c539c)
#         ;
#
#
#
#
#             var circle_15f536a7cf11116ee4b91b569c47c9a6 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bdd31a025e1a2d4a1ef37f8f8868064a);
#
#
#         var popup_77a4579ca8ca352729efe8c52b0d99a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1ead2659922faabd9ceaad58af5b575 = $(`&lt;div id=&quot;html_e1ead2659922faabd9ceaad58af5b575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_77a4579ca8ca352729efe8c52b0d99a1.setContent(html_e1ead2659922faabd9ceaad58af5b575);
#
#
#
#         circle_15f536a7cf11116ee4b91b569c47c9a6.bindPopup(popup_77a4579ca8ca352729efe8c52b0d99a1)
#         ;
#
#
#
#
#             var circle_89f67b12f0b879915aa068c0188fa900 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bdd31a025e1a2d4a1ef37f8f8868064a);
#
#
#         var popup_58ba1ce83e82ba83b13682e6d7fbaf84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dba25cf01725c32530bdab62355a546e = $(`&lt;div id=&quot;html_dba25cf01725c32530bdab62355a546e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_58ba1ce83e82ba83b13682e6d7fbaf84.setContent(html_dba25cf01725c32530bdab62355a546e);
#
#
#
#         circle_89f67b12f0b879915aa068c0188fa900.bindPopup(popup_58ba1ce83e82ba83b13682e6d7fbaf84)
#         ;
#
#
#
#
#             var circle_a709ad77bddd0fa5b296f311fdde6b28 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Sweep heuristic

# %%
def sweep():
    xcoord = [capitals[k][0] for k in capitals]
    ycoord = [capitals[k][1] for k in capitals]
    centres = []
    
    centres = [(sum(xcoord)/len(capitals) , sum(ycoord)/len(capitals)), (0.5*(max(xcoord) + min(xcoord)), 0.5*(max(ycoord) + min(ycoord)))]
    
    best_tour = []; best_tour_cost = float("inf")
    for xc, yc in centres:
        angle = {} # around the center
        for i in capitals:
            angle[i] = math.degrees(math.atan2(capitals[i][1] - yc, capitals[i][0] - xc))
        angle  = [k for k, v in sorted(angle.items(), key=lambda item: item[1])]
        tour = []; tour_cost = 0
        for k in range(len(angle)):
            if k != 0:
                tour.append((angle[k-1], angle[k]))
                tour_cost += dist_matrix[angle[k-1], angle[k]]
            else:
                start = angle[k]
        tour.append((angle[k], start))
        tour_cost += dist_matrix[(angle[k], start)]
        if tour_cost < best_tour_cost:
            best_tour_cost = tour_cost 
            best_tour = tour
    return best_tour, best_tour_cost
            
best_tour, best_tour_cost = sweep()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 16944.46175833539
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5625545df00848292f7563988fe32dfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5625545df00848292f7563988fe32dfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5625545df00848292f7563988fe32dfd = L.map(
#                 &quot;map_5625545df00848292f7563988fe32dfd&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68b8bbcd15e3d7e3fc107300a778bdd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_68b8bbcd15e3d7e3fc107300a778bdd4.addTo(map_5625545df00848292f7563988fe32dfd);
#
#
#             var circle_ad047f960b394a5f57e5d7990f1a66a1 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5625545df00848292f7563988fe32dfd);
#
#
#         var popup_d3242e9f2f4f20f37af64550e732552e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea72cc1e27259ac054c1d7353c9a1f24 = $(`&lt;div id=&quot;html_ea72cc1e27259ac054c1d7353c9a1f24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_d3242e9f2f4f20f37af64550e732552e.setContent(html_ea72cc1e27259ac054c1d7353c9a1f24);
#
#
#
#         circle_ad047f960b394a5f57e5d7990f1a66a1.bindPopup(popup_d3242e9f2f4f20f37af64550e732552e)
#         ;
#
#
#
#
#             var circle_a1c2ad7a67b45cd0ac5c0adc3052f89c = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5625545df00848292f7563988fe32dfd);
#
#
#         var popup_8d1fad52f914301a1f3fdbe5e65531dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cf5178d6f644e6ae2520e4f9c34a4e1 = $(`&lt;div id=&quot;html_9cf5178d6f644e6ae2520e4f9c34a4e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_8d1fad52f914301a1f3fdbe5e65531dc.setContent(html_9cf5178d6f644e6ae2520e4f9c34a4e1);
#
#
#
#         circle_a1c2ad7a67b45cd0ac5c0adc3052f89c.bindPopup(popup_8d1fad52f914301a1f3fdbe5e65531dc)
#         ;
#
#
#
#
#             var circle_98b11fb9a8f8b9698251c8ffa2c96335 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5625545df00848292f7563988fe32dfd);
#
#
#         var popup_b43e6a9d46d65bc471d65ba8deedd5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd61cddcbd10c3b3cef7076ef62e291f = $(`&lt;div id=&quot;html_cd61cddcbd10c3b3cef7076ef62e291f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_b43e6a9d46d65bc471d65ba8deedd5d8.setContent(html_cd61cddcbd10c3b3cef7076ef62e291f);
#
#
#
#         circle_98b11fb9a8f8b9698251c8ffa2c96335.bindPopup(popup_b43e6a9d46d65bc471d65ba8deedd5d8)
#         ;
#
#
#
#
#             var circle_9f5ba8826c8bea3362a3bd2563ea7bbf = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Savings algorithm

# %%
import itertools
start = max(capitals.items(), key=lambda item: (item[1][0], item[1][1]))[0]
unexplored = [k for k in capitals if k != start]
def savings():
    savings = {}
    for k in list(itertools.combinations(capitals, 2)):
        savings[k] = dist_matrix[k[0], start] + dist_matrix[start, k[1]] - dist_matrix[k]
    
    p, q = max(savings, key=savings.get)
    tour = [(p, q)]
    unexplored.remove(p)
    unexplored.remove(q)
    
    while unexplored:
        tmpDict1 = {h: (dist_matrix[p, start] + dist_matrix[start, h] - dist_matrix[p, h], dist_matrix[q, start] + dist_matrix[start, h] - dist_matrix[q, h]) for h in unexplored}
        
        tmpDict2= {}
        for k in tmpDict1:
            if tmpDict1[k][0] > tmpDict1[k][0]:
                tmpDict2[k, p] = tmpDict1[k][0]
            else:
                tmpDict2[k, q] = tmpDict1[k][1]
                
        a, b = max(tmpDict2, key=tmpDict2.get)
        
        if b == p:
            tour.insert(0, (a, p))
        else:
            tour.append((q, a))
        
        p = tour[0][0]
        q = tour[-1][1]
        unexplored.remove(a)
    
    
    
    tour.insert(0, (start, tour[0][0]))
    tour.append((tour[-1][1], start))

    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = savings()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# 15118.210264739335
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_779eb94ff09a9d76f3896a1ed95b317a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_779eb94ff09a9d76f3896a1ed95b317a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_779eb94ff09a9d76f3896a1ed95b317a = L.map(
#                 &quot;map_779eb94ff09a9d76f3896a1ed95b317a&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4f95ce34043784af74c27a1232b5d60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d4f95ce34043784af74c27a1232b5d60.addTo(map_779eb94ff09a9d76f3896a1ed95b317a);
#
#
#             var circle_cca1cc8ee5958f27efab49fb0a01bcbd = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_779eb94ff09a9d76f3896a1ed95b317a);
#
#
#         var popup_b960afc88d1e22e8b29b44efd0ed262e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c67857b8bc2b8a0a250be87405abcea = $(`&lt;div id=&quot;html_6c67857b8bc2b8a0a250be87405abcea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_b960afc88d1e22e8b29b44efd0ed262e.setContent(html_6c67857b8bc2b8a0a250be87405abcea);
#
#
#
#         circle_cca1cc8ee5958f27efab49fb0a01bcbd.bindPopup(popup_b960afc88d1e22e8b29b44efd0ed262e)
#         ;
#
#
#
#
#             var circle_8faf44a8457bd4c54ca69c2f554cbb01 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_779eb94ff09a9d76f3896a1ed95b317a);
#
#
#         var popup_135949d6729217ddfaa0960c409ee1d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40b11f32c62b1b3e37af60466c9a0379 = $(`&lt;div id=&quot;html_40b11f32c62b1b3e37af60466c9a0379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_135949d6729217ddfaa0960c409ee1d6.setContent(html_40b11f32c62b1b3e37af60466c9a0379);
#
#
#
#         circle_8faf44a8457bd4c54ca69c2f554cbb01.bindPopup(popup_135949d6729217ddfaa0960c409ee1d6)
#         ;
#
#
#
#
#             var circle_91eeb59e5edb18db965c8a3d5f8d6902 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_779eb94ff09a9d76f3896a1ed95b317a);
#
#
#         var popup_89fe3567ac029d92e1ee833b58772318 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a25860035ae72aecf9fca596c683051 = $(`&lt;div id=&quot;html_8a25860035ae72aecf9fca596c683051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_89fe3567ac029d92e1ee833b58772318.setContent(html_8a25860035ae72aecf9fca596c683051);
#
#
#
#         circle_91eeb59e5edb18db965c8a3d5f8d6902.bindPopup(popup_89fe3567ac029d92e1ee833b58772318)
#         ;
#
#
#
#
#             var circle_7fcc9a3e2fdb7cd98f090c196df1471e = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Cheapest insertion

# %%
def cheapest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    while unexplored:
        point_cost = {}
        for k in unexplored:
            tmpCost = float("inf"); i = 'NA'; j = 'NA'
            for (a, b) in tour:
                if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                    tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                    i = a; j = b
            point_cost[k, (i, j)] = tmpCost
        k, (i,j) = min(point_cost, key=point_cost.get)
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = cheapest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13584.739353336783
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c0cdcafd5f7f5c549c1ea4ba453466d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c0cdcafd5f7f5c549c1ea4ba453466d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c0cdcafd5f7f5c549c1ea4ba453466d = L.map(
#                 &quot;map_0c0cdcafd5f7f5c549c1ea4ba453466d&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cefd56dd85f5c3f2bce3f1f9b5fa5923 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cefd56dd85f5c3f2bce3f1f9b5fa5923.addTo(map_0c0cdcafd5f7f5c549c1ea4ba453466d);
#
#
#             var circle_cab07953db71c7b3f6cf7a7cbb0a85a8 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c0cdcafd5f7f5c549c1ea4ba453466d);
#
#
#         var popup_d10e9336e8fffc9dab738d8bba9450d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_080bf8ebff32eb7781b84ce0b76910d9 = $(`&lt;div id=&quot;html_080bf8ebff32eb7781b84ce0b76910d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_d10e9336e8fffc9dab738d8bba9450d2.setContent(html_080bf8ebff32eb7781b84ce0b76910d9);
#
#
#
#         circle_cab07953db71c7b3f6cf7a7cbb0a85a8.bindPopup(popup_d10e9336e8fffc9dab738d8bba9450d2)
#         ;
#
#
#
#
#             var circle_f27d0d92807bf891a84492a1bad9afad = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c0cdcafd5f7f5c549c1ea4ba453466d);
#
#
#         var popup_9f85e7171e0d383b75a44569f32587e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db8dfc95fdafa8a6bac99abb07ab8b20 = $(`&lt;div id=&quot;html_db8dfc95fdafa8a6bac99abb07ab8b20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_9f85e7171e0d383b75a44569f32587e9.setContent(html_db8dfc95fdafa8a6bac99abb07ab8b20);
#
#
#
#         circle_f27d0d92807bf891a84492a1bad9afad.bindPopup(popup_9f85e7171e0d383b75a44569f32587e9)
#         ;
#
#
#
#
#             var circle_373699eb2fa54cb36e38745a0a756edc = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c0cdcafd5f7f5c549c1ea4ba453466d);
#
#
#         var popup_b8a311202df0370847f9c05d76b59c18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be21ca806e633f09b5527f1b9166bc50 = $(`&lt;div id=&quot;html_be21ca806e633f09b5527f1b9166bc50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_b8a311202df0370847f9c05d76b59c18.setContent(html_be21ca806e633f09b5527f1b9166bc50);
#
#
#
#         circle_373699eb2fa54cb36e38745a0a756edc.bindPopup(popup_b8a311202df0370847f9c05d76b59c18)
#         ;
#
#
#
#
#             var circle_db9e8f34ab65c7959843cfa34818e910 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Priciest insertion

# %%
def priciest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    while unexplored:
        point_cost = {}
        for k in unexplored:
            tmpCost = float("inf"); i = 'NA'; j = 'NA'
            for (a, b) in tour:
                if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                    tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                    i = a; j = b
            point_cost[k, (i, j)] = tmpCost
        k, (i,j) = max(point_cost, key=point_cost.get)
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = priciest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13562.587061454724
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a165b53913211ac7111c7f3528b7eb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a165b53913211ac7111c7f3528b7eb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a165b53913211ac7111c7f3528b7eb8 = L.map(
#                 &quot;map_1a165b53913211ac7111c7f3528b7eb8&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6b16fd62b88dcf93fe5718ee15a07d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6b16fd62b88dcf93fe5718ee15a07d2.addTo(map_1a165b53913211ac7111c7f3528b7eb8);
#
#
#             var circle_ac2f4cb85a947398a2a6595b96d30f1f = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a165b53913211ac7111c7f3528b7eb8);
#
#
#         var popup_9717a8b8ef30c80d2ebda9ed3eab4b6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8e2e33dbb2f563ac1cceda6867366e8 = $(`&lt;div id=&quot;html_f8e2e33dbb2f563ac1cceda6867366e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_9717a8b8ef30c80d2ebda9ed3eab4b6c.setContent(html_f8e2e33dbb2f563ac1cceda6867366e8);
#
#
#
#         circle_ac2f4cb85a947398a2a6595b96d30f1f.bindPopup(popup_9717a8b8ef30c80d2ebda9ed3eab4b6c)
#         ;
#
#
#
#
#             var circle_98ea43a0cd631d2c53808d2ba800a8d9 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a165b53913211ac7111c7f3528b7eb8);
#
#
#         var popup_6a5d9e4af52912264101341137749ed4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c90dbd1b33265ae67c9d2b92bfe7978 = $(`&lt;div id=&quot;html_3c90dbd1b33265ae67c9d2b92bfe7978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_6a5d9e4af52912264101341137749ed4.setContent(html_3c90dbd1b33265ae67c9d2b92bfe7978);
#
#
#
#         circle_98ea43a0cd631d2c53808d2ba800a8d9.bindPopup(popup_6a5d9e4af52912264101341137749ed4)
#         ;
#
#
#
#
#             var circle_c4146979ebab597684a9e5d2e1f5d441 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a165b53913211ac7111c7f3528b7eb8);
#
#
#         var popup_71213aa8810e5239c6ad2a40a409a225 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f923ebc0512c7498f8bb36cfcf9f7caf = $(`&lt;div id=&quot;html_f923ebc0512c7498f8bb36cfcf9f7caf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_71213aa8810e5239c6ad2a40a409a225.setContent(html_f923ebc0512c7498f8bb36cfcf9f7caf);
#
#
#
#         circle_c4146979ebab597684a9e5d2e1f5d441.bindPopup(popup_71213aa8810e5239c6ad2a40a409a225)
#         ;
#
#
#
#
#             var circle_9b919745582a336d23c1169ba77fca96 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## ## Nearest insertion

# %%
def nearest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    explored = [p, q]

    while unexplored:
        point_cost = {(a, b): dist_matrix[a, b] for a in unexplored for b in explored}
        k, j = min(point_cost, key=point_cost.get)
        
        point_cost = {}
       
        tmpCost = float("inf"); i = 'NA'; j = 'NA'
        for (a, b) in tour:
            if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                i = a; j = b
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = nearest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13638.521699122834
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_522dcc343162d7add9cd217090edacb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_522dcc343162d7add9cd217090edacb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_522dcc343162d7add9cd217090edacb4 = L.map(
#                 &quot;map_522dcc343162d7add9cd217090edacb4&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6d021a62616efc735122179a6a6e423 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6d021a62616efc735122179a6a6e423.addTo(map_522dcc343162d7add9cd217090edacb4);
#
#
#             var circle_920054a8ee57ff8c2aac73fc5043eaa3 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_522dcc343162d7add9cd217090edacb4);
#
#
#         var popup_14e67e9deece43206881cefc8696ed02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16a1678c6548cb776c2c1ad78e5e684a = $(`&lt;div id=&quot;html_16a1678c6548cb776c2c1ad78e5e684a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_14e67e9deece43206881cefc8696ed02.setContent(html_16a1678c6548cb776c2c1ad78e5e684a);
#
#
#
#         circle_920054a8ee57ff8c2aac73fc5043eaa3.bindPopup(popup_14e67e9deece43206881cefc8696ed02)
#         ;
#
#
#
#
#             var circle_c4adffeab97cc83f7c02dbb239404086 = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_522dcc343162d7add9cd217090edacb4);
#
#
#         var popup_340179e323691a28555052fea2d81965 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa44fe060db1d3176223442beb6fd845 = $(`&lt;div id=&quot;html_aa44fe060db1d3176223442beb6fd845&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_340179e323691a28555052fea2d81965.setContent(html_aa44fe060db1d3176223442beb6fd845);
#
#
#
#         circle_c4adffeab97cc83f7c02dbb239404086.bindPopup(popup_340179e323691a28555052fea2d81965)
#         ;
#
#
#
#
#             var circle_9b9baea8b84238bfecf6635870e51154 = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_522dcc343162d7add9cd217090edacb4);
#
#
#         var popup_a2a701d7a48105c8f2239fddf387c19d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_511a738cb33e437385be5d8697f708d9 = $(`&lt;div id=&quot;html_511a738cb33e437385be5d8697f708d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_a2a701d7a48105c8f2239fddf387c19d.setContent(html_511a738cb33e437385be5d8697f708d9);
#
#
#
#         circle_9b9baea8b84238bfecf6635870e51154.bindPopup(popup_a2a701d7a48105c8f2239fddf387c19d)
#         ;
#
#
#
#
#             var circle_f9ce9299d5ce76f377a78a3edc4d53a8 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %% [markdown]
# ## Farthest insertion

# %%
def farthest_insertion():
    dist = {k:dist_matrix[k] for k in dist_matrix if k[0] != k[1]}
    p, q = min(dist, key=dist.get)
    tour = [(p, q)]
    print(p, q)
    unexplored = [k for k in capitals if k != p and k != q]
    explored = [p, q]

    while unexplored:
        tmp2 = -float("inf"); k = 'NA'
        for a in unexplored:
            tmp1 = float("inf"); j = 'NA'
            for b in explored:
                if tmp1 > dist_matrix[a, b]:
                    tmp1 = dist_matrix[a, b]; j = b
            if tmp2 < tmp1:
                tmp2 = tmp1; k = a
                
        
       
        tmpCost = float("inf"); i = 'NA'; j = 'NA'
        for (a, b) in tour:
            if dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b] <  tmpCost:
                tmpCost = dist_matrix[a, k] + dist_matrix[k, b]- dist_matrix[a, b]
                i = a; j = b
        tour.remove((i,j))
        tour.append((i, k))
        tour.append((k,j))
        unexplored.remove(k)
    tour.append((p, q))
    return tour, sum([dist_matrix[k] for k in tour])

best_tour, best_tour_cost = farthest_insertion()
print(best_tour_cost)
draw_tour(best_tour)
# Out:
# ('Shimla', 'Himachal Pradesh') ('Chandigarh', 'Punjab')
# 13548.288647195177
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d6ae213e1267c34ee411e6a102877fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d6ae213e1267c34ee411e6a102877fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d6ae213e1267c34ee411e6a102877fe = L.map(
#                 &quot;map_1d6ae213e1267c34ee411e6a102877fe&quot;,
#                 {
#                     center: [22.473267647058822, 82.07948529411766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_814608fb82b65cb4c9bd240552d87ecc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_814608fb82b65cb4c9bd240552d87ecc.addTo(map_1d6ae213e1267c34ee411e6a102877fe);
#
#
#             var circle_db88e5bbe6d41bfe464b8f8240c1b647 = L.circle(
#                 [16.5194, 80.1807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d6ae213e1267c34ee411e6a102877fe);
#
#
#         var popup_9cf54ee549f47d461223b7b2e6959795 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6255e30548e5b2bd86883dd231a7cc9e = $(`&lt;div id=&quot;html_6255e30548e5b2bd86883dd231a7cc9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Amaravati&#x27;, &#x27;Andhra Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_9cf54ee549f47d461223b7b2e6959795.setContent(html_6255e30548e5b2bd86883dd231a7cc9e);
#
#
#
#         circle_db88e5bbe6d41bfe464b8f8240c1b647.bindPopup(popup_9cf54ee549f47d461223b7b2e6959795)
#         ;
#
#
#
#
#             var circle_caf3ac304f3352f413fabc8a35f9e78d = L.circle(
#                 [27.0841, 93.6053],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d6ae213e1267c34ee411e6a102877fe);
#
#
#         var popup_db17a544920dd9598478518bb56e0274 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77a178b9e769635df9b3f35f8094a541 = $(`&lt;div id=&quot;html_77a178b9e769635df9b3f35f8094a541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Itanagar&#x27;, &#x27;Arunachal Pradesh&#x27;)&lt;/div&gt;`)[0];
#                 popup_db17a544920dd9598478518bb56e0274.setContent(html_77a178b9e769635df9b3f35f8094a541);
#
#
#
#         circle_caf3ac304f3352f413fabc8a35f9e78d.bindPopup(popup_db17a544920dd9598478518bb56e0274)
#         ;
#
#
#
#
#             var circle_4d33e3de9fdecf044c76604105bc3b5a = L.circle(
#                 [26.1445, 91.7362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d6ae213e1267c34ee411e6a102877fe);
#
#
#         var popup_6fbcd73cb8b397583528770bda87e04a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b79311b63a04f3bca37a409799abd72 = $(`&lt;div id=&quot;html_2b79311b63a04f3bca37a409799abd72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(&#x27;Dispur&#x27;, &#x27;Assam&#x27;)&lt;/div&gt;`)[0];
#                 popup_6fbcd73cb8b397583528770bda87e04a.setContent(html_2b79311b63a04f3bca37a409799abd72);
#
#
#
#         circle_4d33e3de9fdecf044c76604105bc3b5a.bindPopup(popup_6fbcd73cb8b397583528770bda87e04a)
#         ;
#
#
#
#
#             var circle_b3ccbc3f55b93bea323bc29071b92009 = L.circle(
#                 [25.5941, 85.1376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo
